# %% [markdown]
# # Align orthologous protein sequences
#
# Take the ortholog sequences for each gene and align them.

# %%
run kondrashov

# %% [markdown]
# Biopython appears to no longer support the wrappers around multiple sequence
# alignment programs.
#
# Writing a wrapper of `muscle` to be used within Jupyter is easy, though.

# %%
#Wrong command, Ignore >>>>>>

def muscle(gene: str) -> None:
    """
    Generate a multiple sequence alignment from a fasta file.

    Parameters
    ----------
    gene : str
        Gene name.
    """    
    # !muscle -align -input fasta/{gene}.fasta -output aln/{gene}.aln

# %% [markdown]
# ### Run this

# %%
def muscle(gene: str) -> None:
    """
    Generate a multiple sequence alignment from a fasta file.

    Parameters
    ----------
    gene : str
        Gene name.
    """    
    # !muscle -maxiters 10 -in fasta/{gene}.fasta -out aln/{gene}.aln

# %%
# !muscle -maxiters 10 -in fasta/ABCD1_copy.fasta -out aln/ABCD1_copy.aln
#/Users/adesinamary/Documents/GitHub/kondrashov/fasta/ABCD1_filtered.fasta 
#/Users/adesinamary/Documents/GitHub/kondrashov/fasta/ABCD1.fasta
#muscle('ABCD1_filtered')
# Out:
# MUSCLE v3.8.1551 by Robert C. Edgar
#
# http://www.drive5.com/muscle
# This software is donated to the public domain.
# Please cite: Edgar, R.C. Nucleic Acids Res 32(5), 1792-97.
#
# ABCD1_copy 58 seqs, lengths min 417, max 846, avg 724
# 00:00:00      2 MB(0%)  Iter   1  100.00%  K-mer dist pass 1
# 00:00:00      2 MB(0%)  Iter   1  100.00%  K-mer dist pass 2
# 00:00:00     31 MB(0%)  Iter   1  100.00%  Align node
# 00:00:00     31 MB(0%)  Iter   1  100.00%  Root alignment
# 00:00:00     36 MB(0%)  Iter   2  100.00%  Refine tree
# 00:00:00     36 MB(0%)  Iter   2  100.00%  Root alignment
# 00:00:00     37 MB(0%)  Iter   2  100.00%  Root alignment
# 00:00:00     37 MB(0%)  Iter   3  100.00%  Refine biparts
# 00:00:00     37 MB(0%)  Iter   4  100.00%  Refine biparts
# 00:00:01     37 MB(0%)  Iter   5  100.00%  Refine biparts
# 00:00:01     37 MB(0%)  Iter   6  100.00%  Refine biparts
# 00:00:01     38 MB(0%)  Iter   7  100.00%  Refine biparts
# ...

# %% [markdown]
# The following cell aligns the ALPL sequences.  To look at the alignment open it in [this viewer
# application](https://alignmentviewer.org/).

# %%
#Troubleshooting to check if the alignment has errors, 
#run fails!
# !muscle -align fasta/ABCD1_allSp.fasta -stratified -output ensemble.efa

# %% [markdown]
# The following cell aligns the ALPL sequences.  To look at the alignment open it in [this viewer
# application](https://alignmentviewer.org/).

# %%
# this should work for the other genes once they're available
for locus in loci:
    print(locus)
    muscle(locus)
# Out:
# ABCD1
#
# MUSCLE v3.8.1551 by Robert C. Edgar
#
# http://www.drive5.com/muscle
# This software is donated to the public domain.
# Please cite: Edgar, R.C. Nucleic Acids Res 32(5), 1792-97.
#
# ABCD1 62 seqs, lengths min 93, max 846, avg 684
# 00:00:00      2 MB(0%)  Iter   1  100.00%  K-mer dist pass 1
# 00:00:00      2 MB(0%)  Iter   1  100.00%  K-mer dist pass 2
# 00:00:00     32 MB(0%)  Iter   1  100.00%  Align node
# 00:00:00     32 MB(0%)  Iter   1  100.00%  Root alignment
# 00:00:00     35 MB(0%)  Iter   2  100.00%  Refine tree
# 00:00:00     35 MB(0%)  Iter   2  100.00%  Root alignment
# 00:00:00     35 MB(0%)  Iter   2  100.00%  Root alignment
# 00:00:01     40 MB(0%)  Iter   3  100.00%  Refine biparts
# 00:00:02     44 MB(0%)  Iter   4  100.00%  Refine biparts
# 00:00:02     44 MB(0%)  Iter   5  100.00%  Refine biparts
# 00:00:02     44 MB(0%)  Iter   5  100.00%  Refine biparts
# ALPL
#
# MUSCLE v3.8.1551 by Robert C. Edgar
#
# http://www.drive5.com/muscle
# ...
