# %% [markdown]
# # Align orthologous protein sequences
#
# Take the ortholog sequences for each gene and align them.

# %%
run kondrashov

# %% [markdown]
# Biopython appears to no longer support the wrappers around multiple sequence
# alignment programs.
#
# Writing a wrapper of `muscle` to be used within Jupyter is easy, though.
#
# Ignore command

# %%
#Wrong command, Ignore >>>>>>

def muscle(gene: str) -> None:
    """
    Generate a multiple sequence alignment from a fasta file.

    Parameters
    ----------
    gene : str
        Gene name.
    """    
    # !muscle -align -input fasta/{gene}.fasta -output aln/{gene}.aln

# %%
import os
os.makedirs('aln_lociii_match', exist_ok=True)

# %%
def muscle(gene: str) -> None:
    """
    Generate a multiple sequence alignment from a fasta file.

    Parameters
    ----------
    gene : str
        Gene name.
    """    
    # !muscle -maxiters 10 -in fasta_match/{gene}.fasta -out aln_match/{gene}.aln

# %%
muscle('ALPL_match')
# Out:
# MUSCLE v3.8.1551 by Robert C. Edgar
#
# http://www.drive5.com/muscle
# This software is donated to the public domain.
# Please cite: Edgar, R.C. Nucleic Acids Res 32(5), 1792-97.
#
#
# *** ERROR ***  Cannot open 'fasta/ALPL_match.fasta' errno=2

# %% [markdown]
# ### The following cell aligns the sequences per gene.  To look at the alignment open it in [this viewer application](https://alignmentviewer.org/).

# %%
# this should work for the other genes once they're available
for gene in loci:
    print(gene)
    muscle(gene)
# Out:
# ABCD1
#
# MUSCLE v3.8.1551 by Robert C. Edgar
#
# http://www.drive5.com/muscle
# This software is donated to the public domain.
# Please cite: Edgar, R.C. Nucleic Acids Res 32(5), 1792-97.
#
# ABCD1 62 seqs, lengths min 93, max 846, avg 684
# 00:00:00      2 MB(0%)  Iter   1  100.00%  K-mer dist pass 1
# 00:00:00      2 MB(0%)  Iter   1  100.00%  K-mer dist pass 2
# 00:00:00     32 MB(0%)  Iter   1  100.00%  Align node
# 00:00:00     32 MB(0%)  Iter   1  100.00%  Root alignment
# 00:00:00     35 MB(0%)  Iter   2  100.00%  Refine tree
# 00:00:00     35 MB(0%)  Iter   2  100.00%  Root alignment
# 00:00:00     35 MB(0%)  Iter   2  100.00%  Root alignment
# 00:00:01     40 MB(0%)  Iter   3  100.00%  Refine biparts
# 00:00:02     44 MB(0%)  Iter   4  100.00%  Refine biparts
# 00:00:02     44 MB(0%)  Iter   5  100.00%  Refine biparts
# 00:00:02     44 MB(0%)  Iter   5  100.00%  Refine biparts
# ALPL
#
# MUSCLE v3.8.1551 by Robert C. Edgar
#
# http://www.drive5.com/muscle
# ...

# %%
os.getcwd()
os.chdir('/Users/adesinamary/Documents/GitHub/kondrashov')
os.listdir('fasta_match')
# Out:
# ['VWF_NP_000543.3_match.fasta',
#  'RHO_NP_000530.1_match.fasta',
#  'CBS_NP_000062.1_match.fasta',
#  'ATP7B_NP_000044.2_match.fasta',
#  'LDLR_NP_000518.1_match.fasta',
#  'CASR_NP_000379.3_match.fasta',
#  'CYBB_NP_000388.2_match.fasta',
#  'MPZ_NP_000521.2_match.fasta',
#  'ALPL_NP_000469.3_match.fasta',
#  'HPRT1_NP_000185.1_match.fasta',
#  'AR_NP_000035.2_match.fasta',
#  'G6PD_NP_000393.4_match.fasta',
#  'KCNH2_NP_000229.1_match.fasta',
#  'F8_NP_000123.1_match.fasta',
#  'GJB1_NP_001091111.1_match.fasta',
#  'TTR_NP_000362.1_match.fasta',
#  'KCNQ1_NP_000209.2_match.fasta',
#  'GALT_NP_000146.2_match.fasta',
#  'L1CAM_NP_001265045.1_match.fasta',
#  'GBA1_NP_000148.2_match.fasta',
#  'TP53_NP_000537.3_match.fasta',
#  'F7_NP_062562.1_match.fasta',
#  'PAH_NP_000268.1_match.fasta',
#  'G6PD_NP_001346945.1_match.fasta',
#  'BTK_NP_000052.1_match.fasta',
#  'F7_NP_000122.1_match.fasta',
#  'IL2RG_NP_000197.1_match.fasta',
#  'G6PD_NP_001035810.1_match.fasta',
# ...

# %% [markdown]
#  ### Align sequences in fast_match/

# %%
# !muscle -maxiters 10 -in fasta_match/ABCD1_NP_000024.2_match_1.fasta -out aln_match/ABCD1_NP_000024.2_match_1.aln
# Out:
# 95736.21s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# MUSCLE v3.8.1551 by Robert C. Edgar
#
# http://www.drive5.com/muscle
# This software is donated to the public domain.
# Please cite: Edgar, R.C. Nucleic Acids Res 32(5), 1792-97.
#
# ABCD1_NP_000024.2_match_1 30 seqs, lengths min 734, max 785, avg 745
# 00:00:00      2 MB(0%)  Iter   1  100.00%  K-mer dist pass 1
# 00:00:00      2 MB(0%)  Iter   1  100.00%  K-mer dist pass 2
# 00:00:00     18 MB(0%)  Iter   1  100.00%  Align node
# 00:00:00     18 MB(0%)  Iter   1  100.00%  Root alignment
# 00:00:00     19 MB(0%)  Iter   2  100.00%  Refine tree
# 00:00:00     19 MB(0%)  Iter   2  100.00%  Root alignment
# 00:00:00     19 MB(0%)  Iter   2  100.00%  Root alignment
# 00:00:00     19 MB(0%)  Iter   3  100.00%  Refine biparts
# 00:00:00     19 MB(0%)  Iter   4  100.00%  Refine biparts
# 00:00:00     19 MB(0%)  Iter   5  100.00%  Refine biparts
# ...

# %% [markdown]
# ## Run this

# %%
import os
os.makedirs('aln_lociii_match', exist_ok= True)

# %%
import glob
for fasta_file in glob.glob("fasta_lociii_match/*.fasta"):
    base = os.path.splitext(os.path.basename(fasta_file))[0]
    aln_file = f"aln_lociii_match/{base}.aln"

    # !muscle -maxiters 10 -in "{fasta_file}" -out "{aln_file}"
print('Done!')

# %%
ls aln_lociii_match
# Out:
# ABCA12_NP_775099.2_match.aln      HPRT1_NP_000185.1_match.aln
# ABCD1_NP_000024.2_match.aln       HPS3_NP_115759.2_match.aln
# ACAD9_NP_054768.2_match.aln       IL2RG_NP_000197.1_match.aln
# ACADM_NP_000007.1_match.aln       ITGA2B_NP_000410.2_match.aln
# ACADVL_NP_000009.1_match.aln      IVD_NP_002216.3_match.aln
# ACAT1_NP_000010.1_match.aln       KCNH2_NP_000229.1_match.aln
# ADA_NP_000013.2_match.aln         KCNQ1_NP_000209.2_match.aln
# AGL_NP_000633.2_match.aln         KRIT1_NP_919436.1_match.aln
# AGXT_NP_000021.1_match.aln        L1CAM_NP_001265045.1_match.aln
# AHI1_NP_001128303.1_match.aln     LDLR_NP_000518.1_match.aln
# AIRE_NP_000374.1_match.aln        LIPA_NP_000226.2_match.aln
# ALMS1_NP_001365383.1_match.aln    LOXHD1_NP_001371403.1_match.aln
# ALOX12B_NP_001130.1_match.aln     LPL_NP_000228.1_match.aln
# ALPL_NP_000469.3_match.aln        LRPPRC_NP_573566.2_match.aln
# ANK1_NP_000028.3_match.aln        LYST_NP_000072.2_match.aln
# ...
