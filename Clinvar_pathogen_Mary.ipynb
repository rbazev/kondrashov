# %% [markdown]
# # ----------------------------------------
# # Clinvar

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

# %% [markdown]
# ## Download [Variant_summary.txt.gz](https://ftp.ncbi.nlm.nih.gov/pub/clinvar/tab_delimited/) from Clinvar database
# last modified on Clinvar; 2026-09-14 09:55:03
#           Downloaded; Sep 22, 2026
# #### This file is a compilation of all gene variants and classification

# %% [markdown]
# ## Step 1.  fiLTER Database from Clinvar

# %%
Clinvar_main= pd.read_csv("/Users/adesinamary/Downloads/variant_summary-2.txt", sep="\t")
# Out:
# /var/folders/31/rr38lns17x78c7dt588fmqmw0000gs/T/ipykernel_66941/768793125.py:1: DtypeWarning: Columns (0: Chromosome) have mixed types. Specify dtype option on import or set low_memory=False.
#   Clinvar_main= pd.read_csv("/Users/adesinamary/Downloads/variant_summary-2.txt", sep="\t")

# %%
pd.set_option('display.max_columns', 50)
Clinvar_main.head(5)
#Clinvar_main.columns
# Out:
#    #AlleleID                       Type  \
# 0      15041                      Indel
# 1      15041                      Indel
# 2      15042                   Deletion
# 3      15042                   Deletion
# 4      15043  single nucleotide variant
#
#                                                 Name  GeneID GeneSymbol  \
# 0  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 1  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 2     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 3     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 4       NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)    9640     ZNF592
#
#       HGNC_ID          ClinicalSignificance  ClinSigSimple LastEvaluated  \
# 0  HGNC:22197  Pathogenic/Likely pathogenic              1  Dec 17, 2024
# 1  HGNC:22197  Pathogenic/Likely pathogenic              1  Dec 17, 2024
# 2  HGNC:22197                    Pathogenic              1  Jun 29, 2010
# 3  HGNC:22197                    Pathogenic              1  Jun 29, 2010
# 4  HGNC:28986        Uncertain significance              0  Jun 29, 2015
#
#    RS# (dbSNP) nsv/esv (dbVar)                            RCVaccession  \
# 0    397704705               -  RCV000000012|RCV005255549|RCV004998069
# 1    397704705               -  RCV000000012|RCV005255549|RCV004998069
# 2    397704709               -                            RCV000000013
# 3    397704709               -                            RCV000000013
# 4    150829393               -                            RCV000000014
#
#                                         PhenotypeIDS  \
# 0  MONDO:MONDO:0013342,MedGen:C3150901,OMIM:61364...
# 1  MONDO:MONDO:0013342,MedGen:C3150901,OMIM:61364...
# 2  MONDO:MONDO:0013342,MedGen:C3150901,OMIM:61364...
# 3  MONDO:MONDO:0013342,MedGen:C3150901,OMIM:61364...
# 4  MONDO:MONDO:0033005,MedGen:C4551772,OMIM:25130...
#
#                                        PhenotypeList            Origin  \
# 0  Hereditary spastic paraplegia 48|Macular dystr...  germline;unknown
# 1  Hereditary spastic paraplegia 48|Macular dystr...  germline;unknown
# 2                   Hereditary spastic paraplegia 48          germline
# 3                   Hereditary spastic paraplegia 48          germline
# 4                          Galloway-Mowat syndrome 1          germline
#
#   OriginSimple Assembly ChromosomeAccession Chromosome     Start      Stop  \
# 0     germline   GRCh37        NC_000007.13          7   4820844   4820847
# 1     germline   GRCh38        NC_000007.14          7   4781213   4781216
# 2     germline   GRCh37        NC_000007.13          7   4827361   4827374
# 3     germline   GRCh38        NC_000007.14          7   4787730   4787743
# 4     germline   GRCh37         NC_000015.9         15  85342440  85342440
#
#   ReferenceAllele AlternateAllele Cytogenetic  \
# 0              na              na      7p22.1
# 1              na              na      7p22.1
# 2              na              na      7p22.1
# 3              na              na      7p22.1
# 4              na              na     15q25.3
#
#                                         ReviewStatus  NumberSubmitters  \
# 0  criteria provided, multiple submitters, no con...                 4
# 1  criteria provided, multiple submitters, no con...                 4
# 2                     no assertion criteria provided                 1
# 3                     no assertion criteria provided                 1
# 4                     no assertion criteria provided                 1
#
#   Guidelines TestedInGTR                                           OtherIDs  \
# 0          -           N                  ClinGen:CA215070,OMIM:613653.0001
# 1          -           N                  ClinGen:CA215070,OMIM:613653.0001
# 2          -           N                  ClinGen:CA215072,OMIM:613653.0002
# 3          -           N                  ClinGen:CA215072,OMIM:613653.0002
# 4          -           N  ClinGen:CA210674,UniProtKB:Q92610#VAR_064583,O...
#
#    SubmitterCategories  VariationID  PositionVCF ReferenceAlleleVCF  \
# 0                    3            2      4820844               GGAT
# 1                    3            2      4781213               GGAT
# 2                    1            3      4827360    GCTGCTGGACCTGCC
# 3                    1            3      4787729    GCTGCTGGACCTGCC
# 4                    1            4     85342440                  G
#
#        AlternateAlleleVCF SomaticClinicalImpact  \
# 0  TGCTGTAAACTGTAACTGTAAA                     -
# 1  TGCTGTAAACTGTAACTGTAAA                     -
# 2                       G                     -
# 3                       G                     -
# 4                       A                     -
#
#   SomaticClinicalImpactLastEvaluated ReviewStatusClinicalImpact Oncogenicity  \
# 0                                  -                          -            -
# 1                                  -                          -            -
# 2                                  -                          -            -
# 3                                  -                          -            -
# 4                                  -                          -            -
#
#   OncogenicityLastEvaluated ReviewStatusOncogenicity  \
# 0                         -                        -
# 1                         -                        -
# 2                         -                        -
# 3                         -                        -
# 4                         -                        -
#
#    SCVsForAggregateGermlineClassification  \
# 0  SCV001451119|SCV005622007|SCV005909190
# 1  SCV001451119|SCV005622007|SCV005909190
# 2                            SCV000020156
# 3                            SCV000020156
# 4                            SCV000020157
#
#   SCVsForAggregateSomaticClinicalImpact  \
# 0                                     -
# 1                                     -
# 2                                     -
# 3                                     -
# 4                                     -
#
#   SCVsForAggregateOncogenicityClassification
# 0                                          -
# 1                                          -
# 2                                          -
# 3                                          -
# 4                                          -

# %%
Clinvar_main.shape
Clinvar_main.dtypes
Clin1= Clinvar_main[[#'#AlleleID', 
    'Type', 'Name', 
    'GeneID', 
    'GeneSymbol', 
    #'HGNC_ID',
       'ClinicalSignificance', 
       #'ClinSigSimple', 'LastEvaluated', 'RS# (dbSNP)',
       #'nsv/esv (dbVar)', 'RCVaccession', 'PhenotypeIDS', 'PhenotypeList',
       #'Origin', 'OriginSimple', 
       'Assembly', 
       #'ChromosomeAccession',
       #'Chromosome', 'Start', 'Stop', 'ReferenceAllele', 'AlternateAllele',
       #'Cytogenetic', 'ReviewStatus', 'NumberSubmitters', 'Guidelines',
       #'TestedInGTR', 'OtherIDs', 'SubmitterCategories', 
       'VariationID',
       #'PositionVCF', 'ReferenceAlleleVCF', 'AlternateAlleleVCF',
       #'SomaticClinicalImpact', 'SomaticClinicalImpactLastEvaluated',
       #'ReviewStatusClinicalImpact', 'Oncogenicity',
       #'OncogenicityLastEvaluated', 'ReviewStatusOncogenicity',
       #'SCVsForAggregateGermlineClassification',
       #'SCVsForAggregateSomaticClinicalImpact',
       #'SCVsForAggregateOncogenicityClassification'
       ]]

# %% [markdown]
# ## Jump to step 2 belowww

# %%
Clinvar_main.shape
# Out:
# (9056310, 43)

# %%
Clin1.shape
# Out:
# (9056310, 7)

# %%
Clin1.head(10)
#Clin1.to_csv("/Users/adesinamary/Documents/variant_summary_filtered.csv", index=False)

# %%
Clin1.ClinicalSignificance.unique().tolist()
# Out:
# ['Pathogenic/Likely pathogenic',
#  'Pathogenic',
#  'Uncertain significance',
#  'Likely pathogenic',
#  'Conflicting classifications of pathogenicity',
#  'Pathogenic/Pathogenic, low penetrance; risk factor',
#  'Conflicting classifications of pathogenicity; other',
#  'Benign',
#  'risk factor',
#  'Likely benign',
#  'association',
#  'Benign/Likely benign',
#  'no classification for the single variant',
#  'Conflicting classifications of pathogenicity; risk factor',
#  'drug response',
#  'Affects',
#  'Benign; drug response',
#  'Likely benign; drug response',
#  'Conflicting classifications of pathogenicity; association; risk factor',
#  'Pathogenic; risk factor',
#  'Benign; risk factor',
#  'no classifications from unflagged records',
#  'Benign/Likely benign; other',
#  'Pathogenic/Likely pathogenic; risk factor',
#  'Benign; other',
#  'not provided',
#  'protective; risk factor',
#  'Likely benign; other',
#  'Pathogenic/Likely pathogenic/Pathogenic, low penetrance',
#  'Conflicting classifications of pathogenicity; association',
#  'Pathogenic; Affects',
#  'Benign/Likely benign; association',
#  'association; drug response; risk factor',
#  'Benign/Likely benign; other; risk factor',
#  'Benign; protective',
#  'Pathogenic/Likely pathogenic/Likely pathogenic, low penetrance',
#  'drug response; risk factor',
#  'Pathogenic; drug response',
#  'protective',
#  'Likely risk allele',
#  'Uncertain significance/Uncertain risk allele',
#  'Conflicting classifications of pathogenicity; protective',
#  'Uncertain significance; risk factor',
#  'drug response; other',
#  'Likely benign; drug response; other',
#  '-',
#  'Uncertain significance; drug response',
#  'Likely pathogenic; drug response',
#  'other',
#  'Pathogenic; other',
#  'Conflicting classifications of pathogenicity; drug response; other',
#  'Conflicting classifications of pathogenicity; drug response',
#  'Benign; association',
#  'Likely pathogenic; association',
#  'Pathogenic/Likely pathogenic/Pathogenic, low penetrance/Established risk allele; risk factor',
#  'Pathogenic/Likely risk allele',
#  'Likely pathogenic/Likely risk allele',
#  'Pathogenic/Likely pathogenic/Likely risk allele',
#  'Conflicting classifications of pathogenicity; other; risk factor',
#  'Pathogenic; protective',
#  'other; risk factor',
#  'Uncertain significance; other',
#  'Pathogenic/Likely pathogenic; other',
#  'Likely pathogenic, low penetrance',
#  'Pathogenic, low penetrance',
#  'Benign/Likely benign; drug response; other',
#  'Benign; Affects',
#  'Pathogenic/Pathogenic, low penetrance; other',
#  'association; protective',
#  'Likely benign; Affects; association',
#  'Pathogenic/Likely pathogenic/Pathogenic, low penetrance; other',
#  'conflicting data from submitters',
#  'Uncertain significance; Pathogenic/Likely pathogenic',
#  'Uncertain significance/VUS-high',
#  'Uncertain risk allele; risk factor',
#  'Pathogenic/Likely pathogenic; drug response',
#  'Pathogenic/Likely pathogenic; association',
#  'VUS-high',
#  'Uncertain significance/VUS-mid',
#  'Likely benign; risk factor',
#  'Benign/Likely benign; drug response',
#  'Benign/Likely benign; risk factor',
#  'Pathogenic/Pathogenic, low penetrance',
#  'Uncertain risk allele',
#  'Benign; confers sensitivity',
#  'Uncertain significance; association',
#  'Likely pathogenic/Pathogenic, low penetrance',
#  'association; risk factor',
#  'Pathogenic; confers sensitivity',
#  'Conflicting classifications of pathogenicity; Affects',
#  'Pathogenic; association',
#  'Likely pathogenic; Affects',
#  'association not found',
#  'Likely pathogenic; risk factor',
#  'Likely benign; association',
#  'Likely pathogenic; protective',
#  'Benign; Affects; association; other',
#  'Pathogenic/Likely pathogenic/Established risk allele',
#  'VUS-mid',
#  'Uncertain significance; Affects',
#  'confers sensitivity',
#  'confers sensitivity; other',
#  'Established risk allele; association',
#  'Likely pathogenic/Likely pathogenic, low penetrance',
#  'Pathogenic/Likely pathogenic, low penetrance',
#  'Uncertain significance/VUS-low',
#  'VUS-low',
#  'Established risk allele']

# %% [markdown]
# terms = ["Pathogenic", "Likely pathogenic", "Pathogenic/Likely pathogenic", "Pathogenic, low penetrance", "Likely pathogenic, low penetrance"]
#
# #for gene in ["ABCD1"]:
#     filtered = Clin[
#         (Clin2["GeneSymbol"] == "ABCD1" )&
#         (Clin2["ClinicalSignificance"].isin (terms)) &
#         (Clin2["Type"] == "single nucleotide variant") &
#         (Clin2["Assembly"] == "GRCh38")
#         ]
#     #filtered.to_csv(f"clinvar/{gene}.txt", sep="\t", index= False)
#     #print(f"{gene}: {len(filtered)} variants written to clinvar/{gene}.txt")

# %%
terms = ["Pathogenic", "Likely pathogenic", "Pathogenic/Likely pathogenic", "Pathogenic, low penetrance", "Likely pathogenic, low penetrance"]

#for gene in ["ABCD1"]:
variant_summary_filtered_ABCD1 = Clin1[
    (Clin1["GeneSymbol"] == "ABCD1" )&
    (Clin1["ClinicalSignificance"].isin (terms)) &
    (Clin1["Type"] == "single nucleotide variant")&
    (Clin1["Assembly"] == "GRCh38")
    ]
#variant_summary_filtered_ABCD1.to_csv("/Users/adesinamary/Documents/variant_summary_filtered_ABCD1.csv", index=False)

variant_summary_filtered_ABCD1
# Out:
#                               Type  \
# 20554    single nucleotide variant
# 20556    single nucleotide variant
# 20558    single nucleotide variant
# 20560    single nucleotide variant
# 20562    single nucleotide variant
# ...                            ...
# 8915843  single nucleotide variant
# 8977356  single nucleotide variant
# 8980383  single nucleotide variant
# 9046872  single nucleotide variant
# 9050682  single nucleotide variant
#
#                                                Name  GeneID GeneSymbol  \
# 20554     NM_000033.4(ABCD1):c.871G>A (p.Glu291Lys)     215      ABCD1
# 20556    NM_000033.4(ABCD1):c.1451C>G (p.Pro484Arg)     215      ABCD1
# 20558                NM_000033.4(ABCD1):c.1635-2A>G     215      ABCD1
# 20560    NM_000033.4(ABCD1):c.1165C>G (p.Arg389Gly)     215      ABCD1
# 20562     NM_000033.4(ABCD1):c.443A>G (p.Asn148Ser)     215      ABCD1
# ...                                             ...     ...        ...
# 8915843   NM_000033.4(ABCD1):c.796G>C (p.Gly266Arg)     215      ABCD1
# 8977356    NM_000033.4(ABCD1):c.274G>C (p.Gly92Arg)     215      ABCD1
# 8980383  NM_000033.4(ABCD1):c.1256T>C (p.Val419Ala)     215      ABCD1
# 9046872   NM_000033.4(ABCD1):c.886T>G (p.Tyr296Asp)     215      ABCD1
# 9050682  NM_000033.4(ABCD1):c.1619T>G (p.Phe540Cys)     215      ABCD1
#
#                  ClinicalSignificance Assembly  VariationID
# 20554                      Pathogenic   GRCh38        11292
# 20556                      Pathogenic   GRCh38        11293
# 20558                      Pathogenic   GRCh38        11294
# 20560                      Pathogenic   GRCh38        11296
# 20562    Pathogenic/Likely pathogenic   GRCh38        11297
# ...                               ...      ...          ...
# 8915843             Likely pathogenic   GRCh38      4818088
# 8977356             Likely pathogenic   GRCh38      4849478
# 8980383                    Pathogenic   GRCh38      4851269
# 9046872             Likely pathogenic   GRCh38      4885746
# 9050682             Likely pathogenic   GRCh38      4887817
#
# [327 rows x 7 columns]

# %%
variant_summary_filtered_ABCD1.shape
# Out:
# (327, 7)

# %%
#Clin1.GeneSymbol
#Clin1.GeneSymbol.values
Clin1["GeneSymbol"]
list(Clin1["GeneSymbol"])
Clin1.GeneSymbol.nunique()
# Out:
# 41134

# %%
yy= Clin1.GeneSymbol.unique().tolist()
print(len(yy))
yy
# Out:
# 41134
# ['AP5Z1',
#  'ZNF592',
#  'FOXRED1',
#  'NUBPL',
#  'HFE',
#  'WDR35',
#  'ABHD12',
#  'ZNF513',
#  'HOGA1',
#  'FAM161A',
#  'WDR62',
#  'WDPCP',
#  'TBC1D24',
#  'XPNPEP3',
#  'MTRFR',
#  'CEP152',
#  'SDCCAG8',
#  'OPN1SW',
#  'UROD',
#  'LIPA',
#  'HPSE2',
#  'ASAH1',
#  'TCN2',
#  'PCARE',
#  'MIR2861',
#  'TMEM127',
#  'VIPAS39',
#  'POMP',
#  'CBS',
#  'TPRN',
#  'SLC52A3',
#  'OAT',
#  'DPYS',
#  'SH3PXD2B',
#  'ATXN8;ATXN8OS;LOC109461478',
#  'GRXCR1',
#  'TMEM216',
#  'USB1',
#  'KCNJ18',
#  'PEPD',
#  'AGA',
#  'CYB5A',
#  'WDR72',
#  'CYB5R3',
#  'XPC',
#  'DNAAF1',
#  'RBM20',
#  'KLHDC8B',
#  'SERPINF2',
#  'CANT1',
#  'VWF',
#  'TSPAN12',
#  'NEXN',
#  'RETREG1',
#  'NF1',
#  'CTSA',
#  'GM2A',
#  'LOXHD1',
#  'INPP5E',
#  'SDHAF2',
#  'TAT',
#  'UROC1',
#  'HTT',
#  'TMEM126A',
#  'TACO1',
#  'RNASET2',
#  'PGAM2',
#  'NDUFAF3',
#  'TUBB1',
#  'TUBB2B',
#  'SDHAF1',
#  'COQ9',
#  'DPYD',
#  'BCAM',
#  'DUOXA2',
#  'CCBE1',
#  'CPOX',
#  'ALDOB',
#  'PTS',
#  'RNF168',
#  'QDPR',
#  'RFX6',
#  'RSPH4A',
#  'ANK1',
#  'LMBRD1',
#  'FBN2',
#  'DNAAF2',
#  'DCAF17',
#  'EYS',
#  'TMEM70',
#  'LRTOMT',
#  'NDUFAF6',
#  'FECH',
#  'SLC29A3',
#  'NDUFAF5',
#  'KNG1',
#  'PAH',
#  'CILK1',
#  'FASTKD2',
#  'F5',
#  'PROC',
#  'FUCA1',
#  'ADAMTSL2',
#  'GALNS',
#  'ZFP57',
#  'NAT2',
#  'TPCN2',
#  'UQCRQ',
#  'ZNF469',
#  'RBM28',
#  'BEAN1',
#  'TMEM43',
#  'RNF212',
#  'IYD',
#  'CC2D2A',
#  'ZFYVE26',
#  'GIGYF2',
#  'TRAPPC9',
#  'MMADHC',
#  'SACK1H',
#  'ISCU',
#  'SLC16A12',
#  'RFT1',
#  'GPD1L',
#  'NDUFAF4',
#  'NKX2-6',
#  'LMF1',
#  'APC',
#  'KCTD7',
#  'ATP6V0A2',
#  'TTBK2',
#  'SART3',
#  'SLC46A1',
#  'UBIAD1',
#  'MIR96',
#  'FBP1',
#  'UPK3A',
#  'NCR3',
#  'ARSB',
#  'FOXD3',
#  'EMG1',
#  'RARS2',
#  'CISD2',
#  'GUSB',
#  'CYP4F22',
#  'CA2',
#  'MBD5',
#  'PLEKHM1',
#  'GLB1',
#  'DOCK8',
#  'OCA2',
#  'LCA5',
#  'DIP2B',
#  'FANCI',
#  'FANCI;POLG',
#  'RNF135',
#  'ARMS2',
#  'NHEJ1',
#  'CDKAL1',
#  'IFT80',
#  'XPA',
#  'ATXN10',
#  'SLC30A8',
#  'MFSD8',
#  'KLHL7',
#  'FGD4',
#  'ACAD9',
#  'PLEKHG5',
#  'MTMR14',
#  'MIAT',
#  'FAM20C',
#  'SETBP1',
#  'CCDC50',
#  'G6PC3',
#  'FA2H',
#  'OBSL1',
#  'INF2',
#  'FTO',
#  'YARS2',
#  'DARS2',
#  'RPGRIP1L',
#  'PSAT1',
#  'NOBOX',
#  'ZFAT',
#  'CHMP4B',
#  'FLVCR2',
#  'AGL',
#  'SPG11',
#  'SLC25A38',
#  'SLC35D1',
#  'ATG16L1',
#  'DOLK',
#  'STRA6',
#  'DDX25;HYLS1;PUS3',
#  'HIBCH',
#  'BBS12',
#  'PFKM',
#  'WASHC5',
#  'F12',
#  'CYP11B1',
#  'PRCD',
#  'ARHGAP9',
#  'RSPO4',
#  'MARVELD2',
#  'PDSS2',
#  'MAT1A',
#  'GNAS;GNAS-AS1',
#  'WWC1',
#  'HYCC1',
#  'ATP13A2',
#  'SEC23B',
#  'SEC23A',
#  'SAMD9',
#  'HGSNAT',
#  'LAMTOR2',
#  'RAX2',
#  'PALB2',
#  'P3H1',
#  'RNASEH2C',
#  'RNASEH2B',
#  'B3GLCT',
#  'BANK1',
#  'GALNT12',
#  'DOK7',
#  'ORAI1',
#  'PIGV',
#  'PIGM',
#  'ZFYVE27',
#  'TRMU',
#  'ZNF750',
#  'RIN2',
#  'PJVK',
#  'SLC4A11',
#  'MED25',
#  'GLIS3',
#  'CCDC28B',
#  'CCT5',
#  'BBS10',
#  'CEP290',
#  'VANGL1',
#  'ADAMTSL4',
#  'SIAE',
#  'CC2D1A',
#  'ALDH5A1',
#  'CLDN19',
#  'EHBP1',
#  'TMEM67',
#  'MKS1',
#  'SPATA7',
#  'TMPRSS6',
#  'SPATA16',
#  'SI',
#  'SLC24A4',
#  'MMACHC',
#  'SLC34A3',
#  'COQ2',
#  'HMBS',
#  'SLC24A5',
#  'NEK8',
#  'BLOC1S3',
#  'TRIOBP',
#  'ACOX1',
#  'PKLR',
#  'LPL',
#  'NAGLU',
#  'HPD',
#  'SLITRK1',
#  'WDR36',
#  'NLRP7',
#  'NDUFAF2',
#  'NLRP12',
#  'FANCM',
#  'NECTIN4',
#  'RSPO1',
#  'GLRX5',
#  'L2HGDH',
#  'CUL7',
#  'ACADL',
#  'ACADVL',
#  'PLEKHG4',
#  'ALDH3A2',
#  'THAP1',
#  'CHMP2B',
#  'TOPORS',
#  'CYP27B1',
#  'MANBA',
#  'MAN2B1',
#  'HAL',
#  'NDUFA13',
#  'LHFPL5',
#  'PIKFYVE',
#  'ERCC6',
#  'ERCC8',
#  'ERCC8;NDUFAF2',
#  'STOX1',
#  'FIG4',
#  'NIPAL4',
#  'KIFBP',
#  'ESCO2',
#  'CBLIF',
#  'DBH',
#  'MSH2',
#  'SLC25A22',
#  'CYP17A1',
#  'SPRED1',
#  'CPAP',
#  'RAB3GAP2',
#  'CRBN',
#  'LIPI',
#  'GPSM2',
#  'LPAR6',
#  'IQCB1',
#  'MRPS16',
#  'MRAP',
#  'MPLKIP',
#  'SUGCT',
#  'D2HGDH',
#  'REEP1',
#  'PDCD10',
#  'POU6F2',
#  'PNPLA2',
#  'MMUT',
#  'KRT75',
#  'PNKD',
#  'BTD',
#  'HLCS',
#  'ERMAP',
#  'MCCC2',
#  'MCCC1',
#  'LRRK2',
#  'ADAMTS10',
#  'DNAJC19',
#  'CABP4',
#  'ADA',
#  'ADA;PKIG',
#  'FREM2',
#  'FREM1',
#  'ARL13B',
#  'PITPNM3',
#  'ATPAF2',
#  'UNC13D',
#  'SGCG',
#  'AHI1',
#  'SLC6A19',
#  'CHD7',
#  'PPARGC1B',
#  'ARL6',
#  'RDH12',
#  'SUMO4;TAB2',
#  'EFHC1',
#  'GJC2',
#  'GCDH',
#  'GCDH;KLF1;LOC117125594',
#  'GSDME',
#  'PC',
#  'GTF2H5',
#  'ANKK1',
#  'MED13L',
#  'DLAT',
#  'PDHX',
#  'LLGL2;TSEN54',
#  'TSEN54',
#  'TSEN34',
#  'TSEN2',
#  'C1QTNF5',
#  'ALG3',
#  'SLC39A13',
#  'CYP2R1',
#  'DNAAF4',
#  'FIGLA',
#  'NIPBL',
#  'PEX26',
#  'ANO5',
#  'SEC63',
#  'CASP12',
#  'ROBO3',
#  'STRADA',
#  'CYP4V2',
#  'NPSR1',
#  'RP1L1',
#  'GRHL2',
#  'MYH14',
#  'VPS33B',
#  'HMCN1',
#  'VKORC1',
#  'VHL',
#  'NCF2',
#  'NCF1',
#  'CYBA',
#  'MFN2',
#  'PRICKLE1',
#  'SETX',
#  'PYGM',
#  'ETHE1',
#  'SYNE2',
#  'SYNE1',
#  'CHST14',
#  'MCEE',
#  'PLCE1',
#  'USH2A',
#  'SLC9A9',
#  'CERKL',
#  'HJV',
#  '-',
#  'BCKDHA',
#  'SLC36A2',
#  'ARG1',
#  'ASL',
#  'PINK1',
#  'CPS1',
#  'NAGS',
#  'IGF2BP2',
#  'KIF21A',
#  'NEU1',
#  'SCN4B',
#  'KRT74',
#  'ADSL',
#  'MASTL',
#  'SCN3B',
#  'EXT2',
#  'SH3TC2',
#  'UNC93B1',
#  'CDK5RAP2',
#  'SPG21',
#  'EXT1',
#  'CACNA2D4',
#  'SEMA3E',
#  'SOX9',
#  'SATB2',
#  'NIPA1',
#  'NSMF',
#  'ARHGEF10',
#  'ASPN;CENPP',
#  'TTC8',
#  'XYLT2',
#  'XYLT1',
#  'FANCL',
#  'PUS1',
#  'MEFV',
#  'ALG8',
#  'CLN5',
#  'PALLD',
#  'APOC4-APOC2;APOC2',
#  'APOC2',
#  'NHLRC1',
#  'ETFA',
#  'ANTXR2',
#  'ASPA',
#  'HSPB8',
#  'NPC1L1',
#  'SIL1',
#  'NPHP3',
#  'TPP1',
#  'GORAB',
#  'COX4I2',
#  'BBS9',
#  'SUMF1',
#  'SUMF2',
#  'CCM2',
#  'WHRN',
#  'A4GALT',
#  'ALG2',
#  'CACNA1H',
#  'FERMT3',
#  'FERMT1',
#  'DSG4',
#  'BEST1',
#  'LEMD3',
#  'GNPTAB',
#  'GBE1',
#  'GNPTG',
#  'CLN8',
#  'FRAS1',
#  'ZNF365',
#  'VPS13B',
#  'RGS9BP',
#  'ACAT1',
#  'CNNM4',
#  'ABCA12',
#  'MCFD2',
#  'PCSK9',
#  'HSD3B7',
#  'KIRREL3',
#  'ITGA2B',
#  'TAS2R38',
#  'TJP2',
#  'KANK1',
#  'SBF2',
#  'USH1G',
#  'SECISBP2',
#  'SAR1B',
#  'CLCF1',
#  'GNS',
#  'CTH',
#  'OSTM1',
#  'FSCN2',
#  'RAI1',
#  'ATXN7',
#  'XDH',
#  'NPC1',
#  'APBB1;SMPD1',
#  'SMPD1',
#  'KRT9',
#  'KCNV2',
#  'BBS7',
#  'ATM',
#  'ARSA',
#  'MMAB',
#  'EPM2A',
#  'IL23R',
#  'SLC17A8',
#  'LRPPRC',
#  'KCNQ1',
#  'HPS6',
#  'HPS5',
#  'ADAMTS17',
#  'MMAA',
#  'APCDD1',
#  'TPH2',
#  'HGD',
#  'CDAN1',
#  'DYM',
#  'UTP4',
#  'SBDS',
#  'FKTN',
#  'POMT2',
#  'PDSS1',
#  'POMT1',
#  'NME8',
#  'MC2R',
#  'CDC73',
#  'NF2',
#  'LIPH',
#  'AIRE',
#  'SALL4',
#  'GABBR2',
#  'RP9',
#  'SRD5A2',
#  'PRPF3',
#  'PRPF8',
#  'SEMA4A',
#  'FLCN',
#  'EVC2',
#  'TMIE',
#  'IRF5',
#  'NPHP4',
#  'CARD9',
#  'ALOXE3',
#  'IRF6',
#  'TDP1',
#  'PTF1A',
#  'CRELD1',
#  'DTNBP1',
#  'ALG12',
#  'FANCA',
#  'PROKR2',
#  'MCPH1',
#  'SPART',
#  'PAX6',
#  'WT1',
#  'NPHP1',
#  'SLC22A12',
#  'MTHFR',
#  'HYAL1',
#  'FKBP10',
#  'SLC39A4',
#  'IMPG2',
#  'ATXN3',
#  'CLN3',
#  'ABCC11',
#  'OTOA',
#  'IVD',
#  'SUFU',
#  'TRPM6',
#  'ACADM',
#  'PROK2',
#  'EHMT1',
#  'GALT',
#  'MPO',
#  'LPO;MPO',
#  'COQ8A',
#  'COG8',
#  'COG7',
#  'COG4',
#  'COG1',
#  'LCAT',
#  'GALE',
#  'LDLR',
#  'LDLR;MIR6886',
#  'ALG9',
#  'UROS',
#  'TRPM4',
#  'TYR',
#  'LYST',
#  'GALC',
#  'SUOX',
#  'ACADS',
#  'IRAK4',
#  'ATP7B',
#  'PHGDH',
#  'HEXB',
#  'HEXA',
#  'SERPING1',
#  'GCLC',
#  'TCOF1',
#  'ALMS1',
#  'RB1CC1',
#  'FXN',
#  'POMGNT1',
#  'COG5',
#  'ALDH4A1',
#  'PRODH',
#  'MYO3A',
#  'FTCD',
#  'GAA',
#  'ST14',
#  'TPO',
#  'MLYCD',
#  'DUOX2',
#  'SAMHD1',
#  'TLL1',
#  'CLN6',
#  'SLC26A2',
#  'PRSS12',
#  'TMC1',
#  'PKHD1',
#  'EIF2B4',
#  'EIF2B1',
#  'HPS4',
#  'NSD1',
#  'UPB1',
#  'GP1BA',
#  'RXFP2',
#  'GFM1',
#  'NLRP1',
#  'TMPRSS15',
#  'RIMS1',
#  'GNMT',
#  'SMARCAL1',
#  'TREX1',
#  'EDARADD',
#  'GDAP1',
#  'PAX3',
#  'FKRP',
#  'ENAM',
#  'OPA3',
#  'MYLK2',
#  'LZTS1',
#  'MYO5B',
#  'SCGB3A2',
#  'CYP27A1',
#  'MLPH',
#  'SLC25A19',
#  'HAVCR1',
#  'ZMPSTE24',
#  'ITPKC',
#  'NOP10',
#  'NHP2',
#  'HAMP',
#  'GBA1',
#  'EIF2B2',
#  'HTRA2;LOXL3',
#  'HTRA2',
#  'STRC',
#  'ATL1',
#  'EGLN1',
#  'PRPF31',
#  'DHCR24',
#  'NLRP3',
#  'BSND',
#  'ANTXR1',
#  'ITCH',
#  'CLRN1',
#  'CLRN1-AS1;CLRN1',
#  'CATSPER1',
#  'APOA5',
#  'ALS2',
#  'ESPN',
#  'APTX',
#  'PSTPIP1',
#  'SIX6',
#  'EIF2B3',
#  'CTNS',
#  'TNFRSF13C',
#  'WNT10A',
#  'CLEC7A',
#  'TIRAP',
#  'DICER1',
#  'MFRP',
#  'NT5C3A',
#  'SELENON',
#  'SLC45A2',
#  'WFS1',
#  'BHLHE41',
#  'BSCL2',
#  'BSCL2;HNRNPUL2-BSCL2',
#  'PANK2',
#  'MIR103A2;MIR103B2;PANK2',
#  'SLC19A3',
#  'BBS2',
#  'SLC2A10',
#  'RAB23',
#  'SLC2A9',
#  'SLURP1',
#  'HPS3',
#  'PIP5K1C',
#  'TWNK',
#  'SMC3',
#  'TBX20',
#  'IFT122',
#  'CD96',
#  'RNASEH2A',
#  'ALX3',
#  'BTNL2',
#  'HAX1',
#  'KIF1B',
#  'PDP1',
#  'DCLRE1C',
#  'UBR1',
#  'VPS13A',
#  'NOD2',
#  'DPM3',
#  'PCNT',
#  'STIM1',
#  'ANGPTL4',
#  'MLC1',
#  'ALG1',
#  'LDB3',
#  'BRIP1',
#  'SLC35C1',
#  'KCNK9',
#  'DMGDH',
#  'HERC2',
#  'TMC8',
#  'TMC6',
#  'NUP62',
#  'MRPS22',
#  'ZEB2',
#  'AMN',
#  'BCO1',
#  'LDLRAP1',
#  'TUBA8',
#  'SOST',
#  'PRX',
#  'SPTLC2',
#  'SPTLC1',
#  'VAPB',
#  'TRPM7',
#  'FBXO7',
#  'SLC26A4',
#  'SLC35A1',
#  'SLC6A20',
#  'PNKP',
#  'CLDN14',
#  'FOXL2',
#  'HSD17B3',
#  'RTN4R',
#  'RETN',
#  'FGF20',
#  'AIP',
#  'CD244',
#  'LMBR1',
#  'LMBR1;ZRS',
#  'ZRS;LMBR1',
#  'LPIN2',
#  'LPIN1',
#  'CDH23',
#  'PCDH15',
#  'ELOVL4',
#  'TMPRSS3',
#  'CRTAP',
#  'DNAI2',
#  'ASPM',
#  'ABCG8',
#  'ABCG5;ABCG8',
#  'ABCG5',
#  'RPGRIP1',
#  'ADIPOQ',
#  'PRKCH',
#  'TRPV4',
#  'GJB4',
#  'DHH',
#  'ALX4',
#  'MINPP1',
#  'FGF23',
#  'GAN',
#  'AAAS',
#  'DMPK',
#  'ARFGEF2',
#  'ARHGAP26',
#  'ELAC2',
#  'GAD1',
#  'GHRL',
#  'CFHR1;CFHR3',
#  'CYP3A5',
#  'FOXP2',
#  'HDAC4',
#  'CHST6',
#  'OPA1',
#  'CAPN10',
#  'TSC1',
#  'SERPINA10',
#  'CARD14;SGSH',
#  'SGSH',
#  'SGSH;SLC26A11',
#  'JPH3',
#  'NDRG1',
#  'AICDA',
#  'MCOLN1',
#  'USH1C',
#  'ATP6V0A4',
#  'HNMT',
#  'WNK1',
#  'DISC1',
#  'HCN4',
#  'ADCY10',
#  'TOR1A',
#  'MESP2',
#  'CFC1',
#  'ANKH',
#  'ANKH;ANKH-DT',
#  'WWOX',
#  'SPINT2',
#  'AASS',
#  'MASP2',
#  'TAB2',
#  'TREM2',
#  'FRZB',
#  'CNGB3',
#  'TARDBP',
#  'TRIM37',
#  'VSX1',
#  'CYLD',
#  'STX11',
#  'SPINK5',
#  'NHERF1',
#  'SPTBN2',
#  'POLG2',
#  'HPS1',
#  'HPS1;MIR4685',
#  'PRKAG3',
#  'FCN3',
#  'PDE11A',
#  'SLC26A5',
#  'TBCE',
#  'MUTYH',
#  'CTDP1',
#  'TNFRSF13B',
#  'MKKS',
#  'TBX21',
#  'NEUROG3',
#  'SLC12A6',
#  'TAS2R16',
#  'LRAT',
#  'CD207',
#  'EVC',
#  'KL',
#  'ABHD5',
#  'ACAD8',
#  'NPHS2',
#  'SYCP3',
#  'AKR1D1',
#  'TSFM',
#  'TFR2',
#  'TSPYL1',
#  'RRM2B',
#  'LTBP4',
#  'MERTK',
#  'AKAP10',
#  'PTGDR',
#  'HOXA2',
#  'CD209',
#  'SLC40A1',
#  'MAPK8IP1',
#  'ACTN4',
#  'EFEMP2',
#  'NR0B2',
#  'MMP20',
#  'HSPB3',
#  'LGI1',
#  'TBX19',
#  'WRN',
#  'BLM',
#  'KALRN',
#  'TCIRG1',
#  'FCGR2B',
#  'PDGFRL',
#  'AFG3L2',
#  'FBLN5',
#  'FZD4',
#  'CNTNAP2',
#  'ALG6',
#  'ICOS',
#  'ADAMTS2',
#  'IDH3B',
#  'BLNK',
#  'TRIP11',
#  'SACS',
#  'AMACR',
#  'TCAP',
#  'NR2E3',
#  'IRAK3',
#  'SP110',
#  'KCNE3;LIPT2',
#  'KCNE3',
#  'GJB6',
#  'covers 17 genes, none of which curated to show dosage sensitivity',
#  'GPC6',
#  'ST3GAL5',
#  'MLH3',
#  'AREL1;MLH3',
#  'AIPL1',
#  'TRPS1',
#  'ATP2C1',
#  'CHEK2',
#  'DNAI1',
#  'PROM1',
#  'B4GALT7',
#  'PPP2R2B',
#  'SLC17A5',
#  'TINF2',
#  'GALK1',
#  'CST3',
#  'GRHPR',
#  'RAD54B',
#  'AGXT',
#  'PRG4',
#  'SPAST',
#  'SCO2',
#  'LRP4',
#  'STAT5B',
#  'DLC1',
#  'RNF6',
#  'CD2AP',
#  'CRLF1',
#  'SLC34A2',
#  'KRIT1',
#  'CRB1',
#  'SLC27A4',
#  'SLC22A4',
#  'RPL11',
#  'KISS1R',
#  'SLC6A5',
#  'SGCE',
#  'SLC7A9',
#  'TYROBP',
#  'ADAMTS13',
#  'TBX15',
#  'RBBP8',
#  'KCNQ1OT1',
#  'ADGRG1',
#  'MYOT',
#  'GRM6',
#  'EDAR',
#  'PPP1R17',
#  'RGS9',
#  'SEPTIN9',
#  'MPDU1',
#  'RAD50',
#  'EIF2AK3',
#  'AXIN2',
#  'UNC119',
#  'AKAP9',
#  'POLH',
#  'SCN4A',
#  'CLDN16',
#  'KCNMB1',
#  'EIF2B5',
#  'GYG1',
#  'SLC19A2',
#  'RP1',
#  'GPHN',
#  'HABP2',
#  'SUCLA2',
#  'ITM2B',
#  'BAG3',
#  'RAB27A',
#  'SLC25A15',
#  'SLC25A13',
#  'PHOX2B',
#  'DNM1L',
#  'NDUFS6',
#  'NDUFS3',
#  'GNE',
#  'AXIN1',
#  'TGM5',
#  'CHST3',
#  'KCNE2',
#  'LITAF',
#  'RECQL4',
#  'SNCAIP',
#  'KLK4',
#  'APOL1',
#  'ALOX12B',
#  'ELP1',
#  'CLDN1',
#  'GCM2',
#  'SIX3',
#  'CYP7B1',
#  'MOCS2',
#  ...]

# %%
#xx = Clin1["GeneSymbol"] == "ATXN8;ATXN8OS;LOC109461478"
xx= Clin1[(Clin1["GeneSymbol"] == "ATXN8;ATXN8OS;LOC109461478" )]
xx
# Out:
#                Type                                   Name  GeneID  \
# 370  Microsatellite  NR_002717.2(ATXN8OS):n.1103CTG[15_40]      -1
# 371  Microsatellite  NR_002717.2(ATXN8OS):n.1103CTG[15_40]      -1
#
#                      GeneSymbol ClinicalSignificance Assembly  VariationID
# 370  ATXN8;ATXN8OS;LOC109461478               Benign   GRCh37          192
# 371  ATXN8;ATXN8OS;LOC109461478               Benign   GRCh38          192

# %%
lociii = ['AP5Z1',
 'ZNF592',
 'FOXRED1',
 'NUBPL',
 'HFE',
 'WDR35',
 'ABHD12',
 'ZNF513',
 'HOGA1',
 'FAM161A',
 'WDR62',
 'WDPCP',
 'TBC1D24',
 'XPNPEP3',
 'MTRFR',
 'CEP152',
 'SDCCAG8',
 'OPN1SW',
 'UROD',
 'LIPA',
 'HPSE2',
 'ASAH1',
 'TCN2',
 'PCARE',
 'MIR2861',
 'TMEM127',
 'VIPAS39',
 'POMP',
 'CBS',
 'TPRN',
 'SLC52A3',
 'OAT',
 'DPYS',
 'SH3PXD2B',
 'ATXN8;ATXN8OS;LOC109461478',
 'GRXCR1',
 'TMEM216',
 'USB1',
 'KCNJ18',
 'PEPD',
 'AGA',
 'CYB5A',
 'WDR72',
 'CYB5R3',
 'XPC',
 'DNAAF1',
 'RBM20',
 'KLHDC8B',
 'SERPINF2',
 'CANT1',
 'VWF',
 'TSPAN12',
 'NEXN',
 'RETREG1',
 'NF1',
 'CTSA',
 'GM2A',
 'LOXHD1',
 'INPP5E',
 'SDHAF2',
 'TAT',
 'UROC1',
 'HTT',
 'TMEM126A',
 'TACO1',
 'RNASET2',
 'PGAM2',
 'NDUFAF3',
 'TUBB1',
 'TUBB2B',
 'SDHAF1',
 'COQ9',
 'DPYD',
 'BCAM',
 'DUOXA2',
 'CCBE1',
 'CPOX',
 'ALDOB',
 'PTS',
 'RNF168',
 'QDPR',
 'RFX6',
 'RSPH4A',
 'ANK1',
 'LMBRD1',
 'FBN2',
 'DNAAF2',
 'DCAF17',
 'EYS',
 'TMEM70',
 'LRTOMT',
 'NDUFAF6',
 'FECH',
 'SLC29A3',
 'NDUFAF5',
 'KNG1',
 'PAH',
 'CILK1',
 'FASTKD2',
 'F5',
 'PROC',
 'FUCA1',
 'ADAMTSL2',
 'GALNS',
 'ZFP57',
 'NAT2',
 'TPCN2',
 'UQCRQ',
 'ZNF469',
 'RBM28',
 'BEAN1',
 'TMEM43',
 'RNF212',
 'IYD',
 'CC2D2A',
 'ZFYVE26',
 'GIGYF2',
 'TRAPPC9',
 'MMADHC',
 'SACK1H',
 'ISCU',
 'SLC16A12',
 'RFT1',
 'GPD1L',
 'NDUFAF4',
 'NKX2-6',
 'LMF1',
 'APC',
 'KCTD7',
 'ATP6V0A2',
 'TTBK2',
 'SART3',
 'SLC46A1',
 'UBIAD1',
 'MIR96',
 'FBP1',
 'UPK3A',
 'NCR3',
 'ARSB',
 'FOXD3',
 'EMG1',
 'RARS2',
 'CISD2',
 'GUSB',
 'CYP4F22',
 'CA2',
 'MBD5',
 'PLEKHM1',
 'GLB1',
 'DOCK8',
 'OCA2',
 'LCA5',
 'DIP2B',
 'FANCI',
 'FANCI;POLG',
 'RNF135',
 'ARMS2',
 'NHEJ1',
 'CDKAL1',
 'IFT80',
 'XPA',
 'ATXN10',
 'SLC30A8',
 'MFSD8',
 'KLHL7',
 'FGD4',
 'ACAD9',
 'PLEKHG5',
 'MTMR14',
 'MIAT',
 'FAM20C',
 'SETBP1',
 'CCDC50',
 'G6PC3',
 'FA2H',
 'OBSL1',
 'INF2',
 'FTO',
 'YARS2',
 'DARS2',
 'RPGRIP1L',
 'PSAT1',
 'NOBOX',
 'ZFAT',
 'CHMP4B',
 'FLVCR2',
 'AGL',
 'SPG11',
 'SLC25A38',
 'SLC35D1',
 'ATG16L1',
 'DOLK',
 'STRA6',
 'DDX25;HYLS1;PUS3',
 'HIBCH',
 'BBS12',
 'PFKM',
 'WASHC5',
 'F12',
 'CYP11B1',
 'PRCD',
 'ARHGAP9',
 'RSPO4',
 'MARVELD2',
 'PDSS2',
 'MAT1A',
 'GNAS;GNAS-AS1',
 'WWC1',
 'HYCC1',
 'ATP13A2',
 'SEC23B',
 'SEC23A',
 'SAMD9',
 'HGSNAT',
 'LAMTOR2',
 'RAX2',
 'PALB2',
 'P3H1',
 'RNASEH2C',
 'RNASEH2B',
 'B3GLCT',
 'BANK1',
 'GALNT12',
 'DOK7',
 'ORAI1',
 'PIGV',
 'PIGM',
 'ZFYVE27',
 'TRMU',
 'ZNF750',
 'RIN2',
 'PJVK',
 'SLC4A11',
 'MED25',
 'GLIS3',
 'CCDC28B',
 'CCT5',
 'BBS10',
 'CEP290',
 'VANGL1',
 'ADAMTSL4',
 'SIAE',
 'CC2D1A',
 'ALDH5A1',
 'CLDN19',
 'EHBP1',
 'TMEM67',
 'MKS1',
 'SPATA7',
 'TMPRSS6',
 'SPATA16',
 'SI',
 'SLC24A4',
 'MMACHC',
 'SLC34A3',
 'COQ2',
 'HMBS',
 'SLC24A5',
 'NEK8',
 'BLOC1S3',
 'TRIOBP',
 'ACOX1',
 'PKLR',
 'LPL',
 'NAGLU',
 'HPD',
 'SLITRK1',
 'WDR36',
 'NLRP7',
 'NDUFAF2',
 'NLRP12',
 'FANCM',
 'NECTIN4',
 'RSPO1',
 'GLRX5',
 'L2HGDH',
 'CUL7',
 'ACADL',
 'ACADVL',
 'PLEKHG4',
 'ALDH3A2',
 'THAP1',
 'CHMP2B',
 'TOPORS',
 'CYP27B1',
 'MANBA',
 'MAN2B1',
 'HAL',
 'NDUFA13',
 'LHFPL5',
 'PIKFYVE',
 'ERCC6',
 'ERCC8',
 'ERCC8;NDUFAF2',
 'STOX1',
 'FIG4',
 'NIPAL4',
 'KIFBP',
 'ESCO2',
 'CBLIF',
 'DBH',
 'MSH2',
 'SLC25A22',
 'CYP17A1',
 'SPRED1',
 'CPAP',
 'RAB3GAP2',
 'CRBN',
 'LIPI',
 'GPSM2',
 'LPAR6',
 'IQCB1',
 'MRPS16',
 'MRAP',
 'MPLKIP',
 'SUGCT',
 'D2HGDH',
 'REEP1',
 'PDCD10',
 'POU6F2',
 'PNPLA2',
 'MMUT',
 'KRT75',
 'PNKD',
 'BTD',
 'HLCS',
 'ERMAP',
 'MCCC2',
 'MCCC1',
 'LRRK2',
 'ADAMTS10',
 'DNAJC19',
 'CABP4',
 'ADA',
 'ADA;PKIG',
 'FREM2',
 'FREM1',
 'ARL13B',
 'PITPNM3',
 'ATPAF2',
 'UNC13D',
 'SGCG',
 'AHI1',
 'SLC6A19',
 'CHD7',
 'PPARGC1B',
 'ARL6',
 'RDH12',
 'SUMO4;TAB2',
 'EFHC1',
 'GJC2',
 'GCDH',
 'GCDH;KLF1;LOC117125594',
 'GSDME',
 'PC',
 'GTF2H5',
 'ANKK1',
 'MED13L',
 'DLAT',
 'PDHX',
 'LLGL2;TSEN54',
 'TSEN54',
 'TSEN34',
 'TSEN2',
 'C1QTNF5',
 'ALG3',
 'SLC39A13',
 'CYP2R1',
 'DNAAF4',
 'FIGLA',
 'NIPBL',
 'PEX26',
 'ANO5',
 'SEC63',
 'CASP12',
 'ROBO3',
 'STRADA',
 'CYP4V2',
 'NPSR1',
 'RP1L1',
 'GRHL2',
 'MYH14',
 'VPS33B',
 'HMCN1',
 'VKORC1',
 'VHL',
 'NCF2',
 'NCF1',
 'CYBA',
 'MFN2',
 'PRICKLE1',
 'SETX',
 'PYGM',
 'ETHE1',
 'SYNE2',
 'SYNE1',
 'CHST14',
 'MCEE',
 'PLCE1',
 'USH2A',
 'SLC9A9',
 'CERKL',
 'HJV',
 '-',
 'BCKDHA',
 'SLC36A2',
 'ARG1',
 'ASL',
 'PINK1',
 'CPS1',
 'NAGS',
 'IGF2BP2',
 'KIF21A',
 'NEU1',
 'SCN4B',
 'KRT74',
 'ADSL',
 'MASTL',
 'SCN3B',
 'EXT2',
 'SH3TC2',
 'UNC93B1',
 'CDK5RAP2',
 'SPG21',
 'EXT1',
 'CACNA2D4',
 'SEMA3E',
 'SOX9',
 'SATB2',
 'NIPA1',
 'NSMF',
 'ARHGEF10',
 'ASPN;CENPP',
 'TTC8',
 'XYLT2',
 'XYLT1',
 'FANCL',
 'PUS1',
 'MEFV',
 'ALG8',
 'CLN5',
 'PALLD',
 'APOC4-APOC2;APOC2',
 'APOC2',
 'NHLRC1',
 'ETFA',
 'ANTXR2',
 'ASPA',
 'HSPB8',
 'NPC1L1',
 'SIL1',
 'NPHP3',
 'TPP1',
 'GORAB',
 'COX4I2',
 'BBS9',
 'SUMF1',
 'SUMF2',
 'CCM2',
 'WHRN',
 'A4GALT',
 'ALG2',
 'CACNA1H',
 'FERMT3',
 'FERMT1',
 'DSG4',
 'BEST1',
 'LEMD3',
 'GNPTAB',
 'GBE1',
 'GNPTG',
 'CLN8',
 'FRAS1',
 'ZNF365',
 'VPS13B',
 'RGS9BP',
 'ACAT1',
 'CNNM4',
 'ABCA12',
 'MCFD2',
 'PCSK9',
 'HSD3B7',
 'KIRREL3',
 'ITGA2B',
 'TAS2R38',
 'TJP2',
 'KANK1',
 'SBF2',
 'USH1G',
 'SECISBP2',
 'SAR1B',
 'CLCF1',
 'GNS',
 'CTH',
 'OSTM1',
 'FSCN2',
 'RAI1',
 'ATXN7',
 'XDH',
 'NPC1',
 'APBB1;SMPD1',
 'SMPD1',
 'KRT9',
 'KCNV2',
 'BBS7',
 'ATM',
 'ARSA',
 'MMAB',
 'EPM2A',
 'IL23R',
 'SLC17A8',
 'LRPPRC',
 'KCNQ1',
 'HPS6',
 'HPS5',
 'ADAMTS17',
 'MMAA',
 'APCDD1',
 'TPH2',
 'HGD',
 'CDAN1',
 'DYM',
 'UTP4',
 'SBDS',
 'FKTN',
 'POMT2',
 'PDSS1',
 'POMT1',
 'NME8',
 'MC2R',
 'CDC73',
 'NF2',
 'LIPH',
 'AIRE',
 'SALL4',
 'GABBR2',
 'RP9',
 'SRD5A2',
 'PRPF3',
 'PRPF8',
 'SEMA4A',
 'FLCN',
 'EVC2',
 'TMIE',
 'IRF5',
 'NPHP4',
 'CARD9',
 'ALOXE3',
 'IRF6',
 'TDP1',
 'PTF1A',
 'CRELD1',
 'DTNBP1',
 'ALG12',
 'FANCA',
 'PROKR2',
 'MCPH1',
 'SPART',
 'PAX6',
 'WT1',
 'NPHP1',
 'SLC22A12',
 'MTHFR',
 'HYAL1',
 'FKBP10',
 'SLC39A4',
 'IMPG2',
 'ATXN3',
 'CLN3',
 'ABCC11',
 'OTOA',
 'IVD',
 'SUFU',
 'TRPM6',
 'ACADM',
 'PROK2',
 'EHMT1',
 'GALT',
 'MPO',
 'LPO;MPO',
 'COQ8A',
 'COG8',
 'COG7',
 'COG4',
 'COG1',
 'LCAT',
 'GALE',
 'LDLR',
 'LDLR;MIR6886',
 'ALG9',
 'UROS',
 'TRPM4',
 'TYR',
 'LYST',
 'GALC',
 'SUOX',
 'ACADS',
 'IRAK4',
 'ATP7B',
 'PHGDH',
 'HEXB',
 'HEXA',
 'SERPING1',
 'GCLC',
 'TCOF1',
 'ALMS1',
 'RB1CC1',
 'FXN',
 'POMGNT1',
 'COG5',
 'ALDH4A1',
 'PRODH',
 'MYO3A',
 'FTCD',
 'GAA',
 'ST14',
 'TPO',
 'MLYCD',
 'DUOX2',
 'SAMHD1',
 'TLL1',
 'CLN6',
 'SLC26A2',
 'PRSS12',
 'TMC1',
 'PKHD1',
 'EIF2B4',
 'EIF2B1',
 'HPS4',
 'NSD1',
 'UPB1',
 'GP1BA',
 'RXFP2',
 'GFM1',
 'NLRP1',
 'TMPRSS15',
 'RIMS1',
 'GNMT',
 'SMARCAL1',
 'TREX1',
 'EDARADD',
 'GDAP1',
 'PAX3',
 'FKRP',
 'ENAM',
 'OPA3',
 'MYLK2',
 'LZTS1',
 'MYO5B',
 'SCGB3A2',
 'CYP27A1',
 'MLPH',
 'SLC25A19',
 'HAVCR1',
 'ZMPSTE24',
 'ITPKC',
 'NOP10',
 'NHP2',
 'HAMP',
 'GBA1',
 'EIF2B2',
 'HTRA2;LOXL3',
 'HTRA2',
 'STRC',
 'ATL1',
 'EGLN1',
 'PRPF31',
 'DHCR24',
 'NLRP3',
 'BSND',
 'ANTXR1',
 'ITCH',
 'CLRN1',
 'CLRN1-AS1;CLRN1',
 'CATSPER1',
 'APOA5',
 'ALS2',
 'ESPN',
 'APTX',
 'PSTPIP1',
 'SIX6',
 'EIF2B3',
 'CTNS',
 'TNFRSF13C',
 'WNT10A',
 'CLEC7A',
 'TIRAP',
 'DICER1',
 'MFRP',
 'NT5C3A',
 'SELENON',
 'SLC45A2',
 'WFS1',
 'BHLHE41',
 'BSCL2',
 'BSCL2;HNRNPUL2-BSCL2',
 'PANK2',
 'MIR103A2;MIR103B2;PANK2',
 'SLC19A3',
 'BBS2',
 'SLC2A10',
 'RAB23',
 'SLC2A9',
 'SLURP1',
 'HPS3',
 'PIP5K1C',
 'TWNK',
 'SMC3',
 'TBX20',
 'IFT122',
 'CD96',
 'RNASEH2A',
 'ALX3',
 'BTNL2',
 'HAX1',
 'KIF1B',
 'PDP1',
 'DCLRE1C',
 'UBR1',
 'VPS13A',
 'NOD2',
 'DPM3',
 'PCNT',
 'STIM1',
 'ANGPTL4',
 'MLC1',
 'ALG1',
 'LDB3',
 'BRIP1',
 'SLC35C1',
 'KCNK9',
 'DMGDH',
 'HERC2',
 'TMC8',
 'TMC6',
 'NUP62',
 'MRPS22',
 'ZEB2',
 'AMN',
 'BCO1',
 'LDLRAP1',
 'TUBA8',
 'SOST',
 'PRX',
 'SPTLC2',
 'SPTLC1',
 'VAPB',
 'TRPM7',
 'FBXO7',
 'SLC26A4',
 'SLC35A1',
 'SLC6A20',
 'PNKP',
 'CLDN14',
 'FOXL2',
 'HSD17B3',
 'RTN4R',
 'RETN',
 'FGF20',
 'AIP',
 'CD244',
 'LMBR1',
 'LMBR1;ZRS',
 'ZRS;LMBR1',
 'LPIN2',
 'LPIN1',
 'CDH23',
 'PCDH15',
 'ELOVL4',
 'TMPRSS3',
 'CRTAP',
 'DNAI2',
 'ASPM',
 'ABCG8',
 'ABCG5;ABCG8',
 'ABCG5',
 'RPGRIP1',
 'ADIPOQ',
 'PRKCH',
 'TRPV4',
 'GJB4',
 'DHH',
 'ALX4',
 'MINPP1',
 'FGF23',
 'GAN',
 'AAAS',
 'DMPK',
 'ARFGEF2',
 'ARHGAP26',
 'ELAC2',
 'GAD1',
 'GHRL',
 'CFHR1;CFHR3',
 'CYP3A5',
 'FOXP2',
 'HDAC4',
 'CHST6',
 'OPA1',
 'CAPN10',
 'TSC1',
 'SERPINA10',
 'CARD14;SGSH',
 'SGSH',
 'SGSH;SLC26A11',
 'JPH3',
 'NDRG1',
 'AICDA',
 'MCOLN1',
 'USH1C',
 'ATP6V0A4',
 'HNMT',
 'WNK1',
 'DISC1',
 'HCN4',
 'ADCY10',
 'TOR1A',
 'MESP2',
 'CFC1',
 'ANKH',
 'ANKH;ANKH-DT',
 'WWOX',
 'SPINT2',
 'AASS',
 'MASP2',
 'TAB2',
 'TREM2',
 'FRZB',
 'CNGB3',
 'TARDBP',
 'TRIM37',
 'VSX1',
 'CYLD',
 'STX11',
 'SPINK5',
 'NHERF1',
 'SPTBN2',
 'POLG2',
 'HPS1',
 'HPS1;MIR4685',
 'PRKAG3',
 'FCN3',
 'PDE11A',
 'SLC26A5',
 'TBCE',
 'MUTYH',
 'CTDP1',
 'TNFRSF13B',
 'MKKS',
 'TBX21',
 'NEUROG3',
 'SLC12A6',
 'TAS2R16',
 'LRAT',
 'CD207',
 'EVC',
 'KL',
 'ABHD5',
 'ACAD8',
 'NPHS2',
 'SYCP3',
 'AKR1D1',
 'TSFM',
 'TFR2',
 'TSPYL1',
 'RRM2B',
 'LTBP4',
 'MERTK',
 'AKAP10',
 'PTGDR',
 'HOXA2',
 'CD209',
 'SLC40A1',
 'MAPK8IP1',
 'ACTN4',
 'EFEMP2',
 'NR0B2',
 'MMP20',
 'HSPB3',
 'LGI1',
 'TBX19',
 'WRN',
 'BLM',
 'KALRN',
 'TCIRG1',
 'FCGR2B',
 'PDGFRL',
 'AFG3L2',
 'FBLN5',
 'FZD4',
 'CNTNAP2',
 'ALG6',
 'ICOS',
 'ADAMTS2',
 'IDH3B',
 'BLNK',
 'TRIP11',
 'SACS',
 'AMACR',
 'TCAP',
 'NR2E3',
 'IRAK3',
 'SP110',
 'KCNE3;LIPT2',
 'KCNE3',
 'GJB6',
 'GPC6',
 'ST3GAL5',
 'MLH3',
 'AREL1;MLH3',
 'AIPL1',
 'TRPS1',
 'ATP2C1',
 'CHEK2',
 'DNAI1',
 'PROM1',
 'B4GALT7',
 'PPP2R2B',
 'SLC17A5',
 'TINF2',
 'GALK1',
 'CST3',
 'GRHPR',
 'RAD54B',
 'AGXT',
 'PRG4',
 'SPAST',
 'SCO2',
 'LRP4',
 'STAT5B',
 'DLC1',
 'RNF6',
 'CD2AP',
 'CRLF1',
 'SLC34A2',
 'KRIT1',
 'CRB1',
 'SLC27A4',
 'SLC22A4',
 'RPL11',
 'KISS1R',
 'SLC6A5',
 'SGCE',
 'SLC7A9',
 'TYROBP',
 'ADAMTS13',
 'TBX15',
 'RBBP8',
 'KCNQ1OT1',
 'ADGRG1',
 'MYOT',
 'GRM6',
 'EDAR',
 'PPP1R17',
 'RGS9',
 'SEPTIN9',
 'MPDU1',
 'RAD50',
 'EIF2AK3',
 'AXIN2',
 'UNC119',
 'AKAP9',
 'POLH',
 'SCN4A',
 'CLDN16',
 'KCNMB1',
 'EIF2B5',
 'GYG1',
 'SLC19A2',
 'RP1',
 'GPHN',
 'HABP2',
 'SUCLA2',
 'ITM2B',
 'BAG3',
 'RAB27A',
 'SLC25A15',
 'SLC25A13',
 'PHOX2B',
 'DNM1L',
 'NDUFS6',
 'NDUFS3',
 'GNE',
 'AXIN1',
 'TGM5',
 'CHST3',
 'KCNE2',
 'LITAF',
 'RECQL4',
 'SNCAIP',
 'KLK4',
 'APOL1',
 'ALOX12B',
 'ELP1',
 'CLDN1',
 'GCM2',
 'SIX3',
 'CYP7B1',
 'MOCS2'
 ]

# %%
Clin1.head(20)
# Out:
#                          Type  \
# 0                       Indel
# 1                       Indel
# 2                    Deletion
# 3                    Deletion
# 4   single nucleotide variant
# 5   single nucleotide variant
# 6   single nucleotide variant
# 7   single nucleotide variant
# 8   single nucleotide variant
# 9   single nucleotide variant
# 10  single nucleotide variant
# 11  single nucleotide variant
# 12  single nucleotide variant
# 13  single nucleotide variant
# 14  single nucleotide variant
# 15  single nucleotide variant
# 16  single nucleotide variant
# 17  single nucleotide variant
# 18  single nucleotide variant
# 19  single nucleotide variant
#
#                                                  Name  GeneID GeneSymbol  \
# 0   NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 1   NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 2      NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 3      NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 4        NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)    9640     ZNF592
# 5        NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)    9640     ZNF592
# 6         NM_017547.4(FOXRED1):c.694C>T (p.Gln232Ter)   55572    FOXRED1
# 7         NM_017547.4(FOXRED1):c.694C>T (p.Gln232Ter)   55572    FOXRED1
# 8        NM_017547.4(FOXRED1):c.1289A>G (p.Asn430Ser)   55572    FOXRED1
# 9        NM_017547.4(FOXRED1):c.1289A>G (p.Asn430Ser)   55572    FOXRED1
# 10           NM_025152.3(NUBPL):c.166G>A (p.Gly56Arg)   80224      NUBPL
# 11           NM_025152.3(NUBPL):c.166G>A (p.Gly56Arg)   80224      NUBPL
# 12            NM_000410.4(HFE):c.845G>A (p.Cys282Tyr)    3077        HFE
# 13            NM_000410.4(HFE):c.845G>A (p.Cys282Tyr)    3077        HFE
# 14             NM_000410.4(HFE):c.187C>G (p.His63Asp)    3077        HFE
# 15             NM_000410.4(HFE):c.187C>G (p.His63Asp)    3077        HFE
# 16             NM_000410.4(HFE):c.193A>T (p.Ser65Cys)    3077        HFE
# 17             NM_000410.4(HFE):c.193A>T (p.Ser65Cys)    3077        HFE
# 18            NM_000410.4(HFE):c.314T>C (p.Ile105Thr)    3077        HFE
# 19            NM_000410.4(HFE):c.314T>C (p.Ile105Thr)    3077        HFE
#
#                                  ClinicalSignificance Assembly  VariationID
# 0                        Pathogenic/Likely pathogenic   GRCh37            2
# 1                        Pathogenic/Likely pathogenic   GRCh38            2
# 2                                          Pathogenic   GRCh37            3
# 3                                          Pathogenic   GRCh38            3
# 4                              Uncertain significance   GRCh37            4
# 5                              Uncertain significance   GRCh38            4
# 6                                          Pathogenic   GRCh37            5
# 7                                          Pathogenic   GRCh38            5
# 8                                   Likely pathogenic   GRCh37            6
# 9                                   Likely pathogenic   GRCh38            6
# 10       Conflicting classifications of pathogenicity   GRCh37       214885
# 11       Conflicting classifications of pathogenicity   GRCh38       214885
# 12  Pathogenic/Pathogenic, low penetrance; risk fa...   GRCh37            9
# 13  Pathogenic/Pathogenic, low penetrance; risk fa...   GRCh38            9
# 14  Conflicting classifications of pathogenicity; ...   GRCh37           10
# 15  Conflicting classifications of pathogenicity; ...   GRCh38           10
# 16       Conflicting classifications of pathogenicity   GRCh37           11
# 17       Conflicting classifications of pathogenicity   GRCh38           11
# 18                             Uncertain significance   GRCh37           12
# 19                             Uncertain significance   GRCh38           12

# %%
run kondrashov

# %%
terms = ["Pathogenic", "Likely pathogenic", "Pathogenic/Likely pathogenic", "Pathogenic, low penetrance", "Likely pathogenic, low penetrance"]

for gene in locie:
    filtered = Clin1[
        (Clin1["GeneSymbol"] == gene )&
        (Clin1["ClinicalSignificance"].isin (terms)) &
        (Clin1["Type"] == "single nucleotide variant") &
        (Clin1["Assembly"] == "GRCh38")
        ]
    filtered.to_csv(f"/Users/adesinamary/Documents/GitHub/kondrashov/pathogenic_lociii/{gene}.csv", sep="\t", index= False)
    print(f"{gene}: {len(filtered)} variants written to clinvar/{gene}.csv")
##### opppps I forgot to change the print out to '...written to pathogen_lociii'
# Out:
# AAAS: 72 variants written to clinvar/AAAS.csv
# ABCA1: 54 variants written to clinvar/ABCA1.csv
# ABCA12: 134 variants written to clinvar/ABCA12.csv
# ABCA3: 97 variants written to clinvar/ABCA3.csv
# ABCA4: 1088 variants written to clinvar/ABCA4.csv
# ABCB11: 244 variants written to clinvar/ABCB11.csv
# ABCB4: 166 variants written to clinvar/ABCB4.csv
# ABCC2: 117 variants written to clinvar/ABCC2.csv
# ABCC6: 191 variants written to clinvar/ABCC6.csv
# ABCC8: 322 variants written to clinvar/ABCC8.csv
# ABCC9: 78 variants written to clinvar/ABCC9.csv
# ABCD1: 327 variants written to clinvar/ABCD1.csv
# ACAD9: 107 variants written to clinvar/ACAD9.csv
# ACADM: 261 variants written to clinvar/ACADM.csv
# ACADS: 61 variants written to clinvar/ACADS.csv
# ACADVL: 297 variants written to clinvar/ACADVL.csv
# ACAN: 105 variants written to clinvar/ACAN.csv
# ACAT1: 121 variants written to clinvar/ACAT1.csv
# ACO2: 50 variants written to clinvar/ACO2.csv
# ACSF3: 99 variants written to clinvar/ACSF3.csv
# ACTA1: 215 variants written to clinvar/ACTA1.csv
# ACTB: 116 variants written to clinvar/ACTB.csv
# ACTG1: 60 variants written to clinvar/ACTG1.csv
# ACVRL1: 357 variants written to clinvar/ACVRL1.csv
# ADA: 106 variants written to clinvar/ADA.csv
# ADA2: 61 variants written to clinvar/ADA2.csv
# ADAMTS13: 83 variants written to clinvar/ADAMTS13.csv
# ADAMTS2: 50 variants written to clinvar/ADAMTS2.csv
# ADAMTSL4: 69 variants written to clinvar/ADAMTSL4.csv
# ADAR: 63 variants written to clinvar/ADAR.csv
# ADGRG1: 74 variants written to clinvar/ADGRG1.csv
# ADGRV1: 323 variants written to clinvar/ADGRV1.csv
# ADNP: 49 variants written to clinvar/ADNP.csv
# ADSL: 62 variants written to clinvar/ADSL.csv
# AFG2A: 62 variants written to clinvar/AFG2A.csv
# AFG3L2: 55 variants written to clinvar/AFG3L2.csv
# AGA: 73 variants written to clinvar/AGA.csv
# AGL: 316 variants written to clinvar/AGL.csv
# AGXT: 232 variants written to clinvar/AGXT.csv
# AHDC1: 53 variants written to clinvar/AHDC1.csv
# AHI1: 134 variants written to clinvar/AHI1.csv
# AIPL1: 53 variants written to clinvar/AIPL1.csv
# AIRE: 124 variants written to clinvar/AIRE.csv
# ALDH3A2: 97 variants written to clinvar/ALDH3A2.csv
# ALDH5A1: 89 variants written to clinvar/ALDH5A1.csv
# ALDH7A1: 150 variants written to clinvar/ALDH7A1.csv
# ALDOB: 84 variants written to clinvar/ALDOB.csv
# ALG1: 85 variants written to clinvar/ALG1.csv
# ALG6: 79 variants written to clinvar/ALG6.csv
# ALMS1: 444 variants written to clinvar/ALMS1.csv
# ALOX12B: 106 variants written to clinvar/ALOX12B.csv
# ALPK3: 116 variants written to clinvar/ALPK3.csv
# ALPL: 405 variants written to clinvar/ALPL.csv
# ALS2: 77 variants written to clinvar/ALS2.csv
# AMT: 79 variants written to clinvar/AMT.csv
# ANK1: 222 variants written to clinvar/ANK1.csv
# ANK2: 57 variants written to clinvar/ANK2.csv
# ANKRD11: 254 variants written to clinvar/ANKRD11.csv
# ANO5: 129 variants written to clinvar/ANO5.csv
# ANOS1: 50 variants written to clinvar/ANOS1.csv
# APC: 770 variants written to clinvar/APC.csv
# APOB: 128 variants written to clinvar/APOB.csv
# APRT: 50 variants written to clinvar/APRT.csv
# AQP2: 51 variants written to clinvar/AQP2.csv
# AR: 272 variants written to clinvar/AR.csv
# ARG1: 69 variants written to clinvar/ARG1.csv
# ARID1A: 95 variants written to clinvar/ARID1A.csv
# ARID1B: 238 variants written to clinvar/ARID1B.csv
# ARSA: 273 variants written to clinvar/ARSA.csv
# ARSB: 167 variants written to clinvar/ARSB.csv
# ARX: 50 variants written to clinvar/ARX.csv
# ASAH1: 90 variants written to clinvar/ASAH1.csv
# ASH1L: 50 variants written to clinvar/ASH1L.csv
# ASL: 184 variants written to clinvar/ASL.csv
# ASNS: 87 variants written to clinvar/ASNS.csv
# ASPA: 113 variants written to clinvar/ASPA.csv
# ASPM: 154 variants written to clinvar/ASPM.csv
# ASS1: 162 variants written to clinvar/ASS1.csv
# ASXL1: 61 variants written to clinvar/ASXL1.csv
# ASXL3: 87 variants written to clinvar/ASXL3.csv
# ATL1: 84 variants written to clinvar/ATL1.csv
# ATM: 1360 variants written to clinvar/ATM.csv
# ATP1A2: 105 variants written to clinvar/ATP1A2.csv
# ATP1A3: 153 variants written to clinvar/ATP1A3.csv
# ATP2A2: 58 variants written to clinvar/ATP2A2.csv
# ATP6V0A4: 56 variants written to clinvar/ATP6V0A4.csv
# ATP6V1B1: 71 variants written to clinvar/ATP6V1B1.csv
# ATP7A: 146 variants written to clinvar/ATP7A.csv
# ATP7B: 451 variants written to clinvar/ATP7B.csv
# ATP8B1: 98 variants written to clinvar/ATP8B1.csv
# ATR: 70 variants written to clinvar/ATR.csv
# ATRX: 122 variants written to clinvar/ATRX.csv
# AUTS2: 52 variants written to clinvar/AUTS2.csv
# AVPR2: 72 variants written to clinvar/AVPR2.csv
# AXIN2: 69 variants written to clinvar/AXIN2.csv
# BAG3: 66 variants written to clinvar/BAG3.csv
# BAP1: 174 variants written to clinvar/BAP1.csv
# BARD1: 215 variants written to clinvar/BARD1.csv
# BBS1: 130 variants written to clinvar/BBS1.csv
# BBS10: 89 variants written to clinvar/BBS10.csv
# BBS12: 60 variants written to clinvar/BBS12.csv
# BBS2: 133 variants written to clinvar/BBS2.csv
# BBS4: 91 variants written to clinvar/BBS4.csv
# BBS7: 76 variants written to clinvar/BBS7.csv
# BBS9: 97 variants written to clinvar/BBS9.csv
# BCKDHA: 118 variants written to clinvar/BCKDHA.csv
# BCKDHB: 139 variants written to clinvar/BCKDHB.csv
# BCS1L: 90 variants written to clinvar/BCS1L.csv
# BEST1: 280 variants written to clinvar/BEST1.csv
# BLM: 225 variants written to clinvar/BLM.csv
# BMPR1A: 136 variants written to clinvar/BMPR1A.csv
# BMPR2: 246 variants written to clinvar/BMPR2.csv
# BRAF: 118 variants written to clinvar/BRAF.csv
# BRAT1: 62 variants written to clinvar/BRAT1.csv
# BRCA1: 1026 variants written to clinvar/BRCA1.csv
# BRCA2: 1332 variants written to clinvar/BRCA2.csv
# BRIP1: 327 variants written to clinvar/BRIP1.csv
# BTD: 162 variants written to clinvar/BTD.csv
# BTK: 247 variants written to clinvar/BTK.csv
# C3: 52 variants written to clinvar/C3.csv
# CACNA1A: 337 variants written to clinvar/CACNA1A.csv
# CACNA1C: 82 variants written to clinvar/CACNA1C.csv
# CACNA1F: 120 variants written to clinvar/CACNA1F.csv
# CACNA1S: 75 variants written to clinvar/CACNA1S.csv
# CAD: 52 variants written to clinvar/CAD.csv
# CAMTA1: 58 variants written to clinvar/CAMTA1.csv
# CAPN3: 311 variants written to clinvar/CAPN3.csv
# CASK: 132 variants written to clinvar/CASK.csv
# CASQ2: 58 variants written to clinvar/CASQ2.csv
# CASR: 211 variants written to clinvar/CASR.csv
# CBS: 206 variants written to clinvar/CBS.csv
# CC2D2A: 195 variants written to clinvar/CC2D2A.csv
# CCDC39: 79 variants written to clinvar/CCDC39.csv
# CCDC40: 56 variants written to clinvar/CCDC40.csv
# CCDC88C: 63 variants written to clinvar/CCDC88C.csv
# CCM2: 50 variants written to clinvar/CCM2.csv
# CD40LG: 66 variants written to clinvar/CD40LG.csv
# CDC73: 72 variants written to clinvar/CDC73.csv
# CDH1: 224 variants written to clinvar/CDH1.csv
# CDH23: 383 variants written to clinvar/CDH23.csv
# CDHR1: 55 variants written to clinvar/CDHR1.csv
# CDK13: 62 variants written to clinvar/CDK13.csv
# CDKL5: 285 variants written to clinvar/CDKL5.csv
# CDKN2A: 76 variants written to clinvar/CDKN2A.csv
# CEP152: 76 variants written to clinvar/CEP152.csv
# CEP164: 76 variants written to clinvar/CEP164.csv
# CEP250: 59 variants written to clinvar/CEP250.csv
# CEP290: 469 variants written to clinvar/CEP290.csv
# CERKL: 106 variants written to clinvar/CERKL.csv
# CFH: 160 variants written to clinvar/CFH.csv
# CFI: 90 variants written to clinvar/CFI.csv
# CFTR: 776 variants written to clinvar/CFTR.csv
# CHAT: 77 variants written to clinvar/CHAT.csv
# CHD2: 209 variants written to clinvar/CHD2.csv
# CHD3: 97 variants written to clinvar/CHD3.csv
# CHD4: 70 variants written to clinvar/CHD4.csv
# CHD7: 429 variants written to clinvar/CHD7.csv
# CHD8: 136 variants written to clinvar/CHD8.csv
# CHEK2: 299 variants written to clinvar/CHEK2.csv
# CHM: 174 variants written to clinvar/CHM.csv
# CHRNE: 127 variants written to clinvar/CHRNE.csv
# CLCN1: 235 variants written to clinvar/CLCN1.csv
# CLCN4: 49 variants written to clinvar/CLCN4.csv
# CLCN5: 89 variants written to clinvar/CLCN5.csv
# CLCN7: 70 variants written to clinvar/CLCN7.csv
# CLCNKB: 52 variants written to clinvar/CLCNKB.csv
# CLN3: 129 variants written to clinvar/CLN3.csv
# CLN5: 68 variants written to clinvar/CLN5.csv
# CLN6: 68 variants written to clinvar/CLN6.csv
# CLN8: 58 variants written to clinvar/CLN8.csv
# CLRN1: 56 variants written to clinvar/CLRN1.csv
# CLTC: 68 variants written to clinvar/CLTC.csv
# CNGA3: 173 variants written to clinvar/CNGA3.csv
# CNGB1: 115 variants written to clinvar/CNGB1.csv
# CNGB3: 153 variants written to clinvar/CNGB3.csv
# CNTNAP2: 55 variants written to clinvar/CNTNAP2.csv
# COL11A1: 180 variants written to clinvar/COL11A1.csv
# COL11A2: 115 variants written to clinvar/COL11A2.csv
# COL12A1: 84 variants written to clinvar/COL12A1.csv
# COL17A1: 108 variants written to clinvar/COL17A1.csv
# COL18A1: 73 variants written to clinvar/COL18A1.csv
# COL1A1: 892 variants written to clinvar/COL1A1.csv
# COL1A2: 668 variants written to clinvar/COL1A2.csv
# COL27A1: 89 variants written to clinvar/COL27A1.csv
# COL2A1: 771 variants written to clinvar/COL2A1.csv
# COL3A1: 781 variants written to clinvar/COL3A1.csv
# COL4A1: 338 variants written to clinvar/COL4A1.csv
# COL4A2: 61 variants written to clinvar/COL4A2.csv
# COL4A3: 633 variants written to clinvar/COL4A3.csv
# COL4A4: 556 variants written to clinvar/COL4A4.csv
# COL4A5: 1068 variants written to clinvar/COL4A5.csv
# COL5A1: 173 variants written to clinvar/COL5A1.csv
# COL5A2: 51 variants written to clinvar/COL5A2.csv
# COL6A1: 135 variants written to clinvar/COL6A1.csv
# COL6A2: 170 variants written to clinvar/COL6A2.csv
# COL6A3: 137 variants written to clinvar/COL6A3.csv
# COL7A1: 712 variants written to clinvar/COL7A1.csv
# COL9A1: 54 variants written to clinvar/COL9A1.csv
# COLQ: 80 variants written to clinvar/COLQ.csv
# COMP: 152 variants written to clinvar/COMP.csv
# COQ8A: 58 variants written to clinvar/COQ8A.csv
# CP: 60 variants written to clinvar/CP.csv
# CPLANE1: 183 variants written to clinvar/CPLANE1.csv
# CPS1: 262 variants written to clinvar/CPS1.csv
# CPT1A: 113 variants written to clinvar/CPT1A.csv
# CPT2: 84 variants written to clinvar/CPT2.csv
# CRB1: 356 variants written to clinvar/CRB1.csv
# CREBBP: 300 variants written to clinvar/CREBBP.csv
# CSF1R: 65 variants written to clinvar/CSF1R.csv
# CSNK2A1: 69 variants written to clinvar/CSNK2A1.csv
# CSNK2B: 78 variants written to clinvar/CSNK2B.csv
# CSPP1: 58 variants written to clinvar/CSPP1.csv
# CTC1: 67 variants written to clinvar/CTC1.csv
# CTCF: 53 variants written to clinvar/CTCF.csv
# CTNNA1: 88 variants written to clinvar/CTNNA1.csv
# CTNNB1: 108 variants written to clinvar/CTNNB1.csv
# CTNS: 113 variants written to clinvar/CTNS.csv
# CTSC: 54 variants written to clinvar/CTSC.csv
# CTSK: 77 variants written to clinvar/CTSK.csv
# CUBN: 125 variants written to clinvar/CUBN.csv
# CUL3: 59 variants written to clinvar/CUL3.csv
# CUL7: 70 variants written to clinvar/CUL7.csv
# CYBB: 142 variants written to clinvar/CYBB.csv
# CYP11B1: 127 variants written to clinvar/CYP11B1.csv
# CYP11B2: 84 variants written to clinvar/CYP11B2.csv
# CYP17A1: 109 variants written to clinvar/CYP17A1.csv
# CYP19A1: 49 variants written to clinvar/CYP19A1.csv
# CYP1B1: 74 variants written to clinvar/CYP1B1.csv
# CYP21A2: 101 variants written to clinvar/CYP21A2.csv
# CYP27A1: 127 variants written to clinvar/CYP27A1.csv
# CYP27B1: 60 variants written to clinvar/CYP27B1.csv
# CYP4V2: 57 variants written to clinvar/CYP4V2.csv
# DBT: 102 variants written to clinvar/DBT.csv
# DCLRE1C: 103 variants written to clinvar/DCLRE1C.csv
# DCX: 119 variants written to clinvar/DCX.csv
# DDC: 76 variants written to clinvar/DDC.csv
# DDX3X: 226 variants written to clinvar/DDX3X.csv
# DDX41: 66 variants written to clinvar/DDX41.csv
# DEAF1: 80 variants written to clinvar/DEAF1.csv
# DEPDC5: 209 variants written to clinvar/DEPDC5.csv
# DES: 77 variants written to clinvar/DES.csv
# DHCR7: 219 variants written to clinvar/DHCR7.csv
# DICER1: 333 variants written to clinvar/DICER1.csv
# DLD: 79 variants written to clinvar/DLD.csv
# DLG4: 59 variants written to clinvar/DLG4.csv
# DMD: 1195 variants written to clinvar/DMD.csv
# DNAH1: 79 variants written to clinvar/DNAH1.csv
# DNAH11: 353 variants written to clinvar/DNAH11.csv
# DNAH5: 570 variants written to clinvar/DNAH5.csv
# DNAH8: 89 variants written to clinvar/DNAH8.csv
# DNAH9: 103 variants written to clinvar/DNAH9.csv
# DNAI1: 96 variants written to clinvar/DNAI1.csv
# DNAI2: 58 variants written to clinvar/DNAI2.csv
# DNM1: 58 variants written to clinvar/DNM1.csv
# DNMT3A: 131 variants written to clinvar/DNMT3A.csv
# DOCK6: 56 variants written to clinvar/DOCK6.csv
# DOCK8: 62 variants written to clinvar/DOCK8.csv
# DOK7: 60 variants written to clinvar/DOK7.csv
# DPYD: 83 variants written to clinvar/DPYD.csv
# DSG2: 61 variants written to clinvar/DSG2.csv
# DSP: 337 variants written to clinvar/DSP.csv
# DST: 109 variants written to clinvar/DST.csv
# DUOX2: 150 variants written to clinvar/DUOX2.csv
# DYNC1H1: 163 variants written to clinvar/DYNC1H1.csv
# DYNC2H1: 409 variants written to clinvar/DYNC2H1.csv
# DYRK1A: 118 variants written to clinvar/DYRK1A.csv
# DYSF: 539 variants written to clinvar/DYSF.csv
# EBF3: 77 variants written to clinvar/EBF3.csv
# EBP: 60 variants written to clinvar/EBP.csv
# ECHS1: 52 variants written to clinvar/ECHS1.csv
# EDA: 190 variants written to clinvar/EDA.csv
# EDAR: 64 variants written to clinvar/EDAR.csv
# EFTUD2: 98 variants written to clinvar/EFTUD2.csv
# EHMT1: 129 variants written to clinvar/EHMT1.csv
# EIF2AK3: 56 variants written to clinvar/EIF2AK3.csv
# EIF2B5: 92 variants written to clinvar/EIF2B5.csv
# ELAC2: 53 variants written to clinvar/ELAC2.csv
# ELANE: 84 variants written to clinvar/ELANE.csv
# ELN: 84 variants written to clinvar/ELN.csv
# ELP1: 229 variants written to clinvar/ELP1.csv
# EMC1: 60 variants written to clinvar/EMC1.csv
# ENG: 269 variants written to clinvar/ENG.csv
# ENPP1: 66 variants written to clinvar/ENPP1.csv
# EP300: 132 variants written to clinvar/EP300.csv
# EPG5: 127 variants written to clinvar/EPG5.csv
# EPHB4: 78 variants written to clinvar/EPHB4.csv
# ERCC2: 121 variants written to clinvar/ERCC2.csv
# ERCC6: 179 variants written to clinvar/ERCC6.csv
# ERCC8: 80 variants written to clinvar/ERCC8.csv
# ESCO2: 56 variants written to clinvar/ESCO2.csv
# ETFDH: 207 variants written to clinvar/ETFDH.csv
# ETHE1: 53 variants written to clinvar/ETHE1.csv
# EVC: 149 variants written to clinvar/EVC.csv
# EVC2: 174 variants written to clinvar/EVC2.csv
# EXT1: 243 variants written to clinvar/EXT1.csv
# EXT2: 115 variants written to clinvar/EXT2.csv
# EYA1: 115 variants written to clinvar/EYA1.csv
# EYA4: 51 variants written to clinvar/EYA4.csv
# EYS: 485 variants written to clinvar/EYS.csv
# F11: 148 variants written to clinvar/F11.csv
# F5: 65 variants written to clinvar/F5.csv
# F7: 81 variants written to clinvar/F7.csv
# F8: 519 variants written to clinvar/F8.csv
# F9: 275 variants written to clinvar/F9.csv
# FAH: 132 variants written to clinvar/FAH.csv
# FAM161A: 81 variants written to clinvar/FAM161A.csv
# FANCA: 529 variants written to clinvar/FANCA.csv
# FANCC: 150 variants written to clinvar/FANCC.csv
# FANCD2: 154 variants written to clinvar/FANCD2.csv
# FANCG: 108 variants written to clinvar/FANCG.csv
# FANCI: 141 variants written to clinvar/FANCI.csv
# FANCL: 63 variants written to clinvar/FANCL.csv
# FANCM: 86 variants written to clinvar/FANCM.csv
# FAS: 76 variants written to clinvar/FAS.csv
# FBN1: 2368 variants written to clinvar/FBN1.csv
# FBN2: 118 variants written to clinvar/FBN2.csv
# FBXL4: 53 variants written to clinvar/FBXL4.csv
# FBXO11: 106 variants written to clinvar/FBXO11.csv
# FECH: 54 variants written to clinvar/FECH.csv
# FGFR1: 153 variants written to clinvar/FGFR1.csv
# FGFR2: 106 variants written to clinvar/FGFR2.csv
# FGFR3: 57 variants written to clinvar/FGFR3.csv
# FH: 284 variants written to clinvar/FH.csv
# FHL1: 52 variants written to clinvar/FHL1.csv
# FIG4: 76 variants written to clinvar/FIG4.csv
# FKRP: 119 variants written to clinvar/FKRP.csv
# FKTN: 87 variants written to clinvar/FKTN.csv
# FLCN: 159 variants written to clinvar/FLCN.csv
# FLG: 151 variants written to clinvar/FLG.csv
# FLNA: 169 variants written to clinvar/FLNA.csv
# FLNB: 101 variants written to clinvar/FLNB.csv
# FLNC: 253 variants written to clinvar/FLNC.csv
# FLT4: 55 variants written to clinvar/FLT4.csv
# FMO3: 68 variants written to clinvar/FMO3.csv
# FOXC1: 67 variants written to clinvar/FOXC1.csv
# FOXG1: 152 variants written to clinvar/FOXG1.csv
# FOXL2: 66 variants written to clinvar/FOXL2.csv
# FOXP1: 111 variants written to clinvar/FOXP1.csv
# FRAS1: 182 variants written to clinvar/FRAS1.csv
# FREM2: 54 variants written to clinvar/FREM2.csv
# FUCA1: 57 variants written to clinvar/FUCA1.csv
# G6PC1: 120 variants written to clinvar/G6PC1.csv
# G6PD: 207 variants written to clinvar/G6PD.csv
# GAA: 476 variants written to clinvar/GAA.csv
# GABRA1: 71 variants written to clinvar/GABRA1.csv
# GABRB2: 60 variants written to clinvar/GABRB2.csv
# GABRB3: 93 variants written to clinvar/GABRB3.csv
# GABRG2: 91 variants written to clinvar/GABRG2.csv
# GALC: 247 variants written to clinvar/GALC.csv
# GALK1: 58 variants written to clinvar/GALK1.csv
# GALNS: 237 variants written to clinvar/GALNS.csv
# GALT: 255 variants written to clinvar/GALT.csv
# GAMT: 88 variants written to clinvar/GAMT.csv
# GATA2: 87 variants written to clinvar/GATA2.csv
# GATAD2B: 56 variants written to clinvar/GATAD2B.csv
# GBA1: 293 variants written to clinvar/GBA1.csv
# GBE1: 121 variants written to clinvar/GBE1.csv
# GCDH: 262 variants written to clinvar/GCDH.csv
# GCH1: 77 variants written to clinvar/GCH1.csv
# GCK: 521 variants written to clinvar/GCK.csv
# GDAP1: 62 variants written to clinvar/GDAP1.csv
# GFAP: 70 variants written to clinvar/GFAP.csv
# GFM1: 104 variants written to clinvar/GFM1.csv
# GJA1: 55 variants written to clinvar/GJA1.csv
# GJB1: 204 variants written to clinvar/GJB1.csv
# GJB2: 180 variants written to clinvar/GJB2.csv
# GLA: 772 variants written to clinvar/GLA.csv
# GLB1: 229 variants written to clinvar/GLB1.csv
# GLDC: 353 variants written to clinvar/GLDC.csv
# GLE1: 85 variants written to clinvar/GLE1.csv
# GLI3: 83 variants written to clinvar/GLI3.csv
# GLRA1: 60 variants written to clinvar/GLRA1.csv
# GNAO1: 85 variants written to clinvar/GNAO1.csv
# GNAS: 148 variants written to clinvar/GNAS.csv
# GNB1: 51 variants written to clinvar/GNB1.csv
# GNE: 137 variants written to clinvar/GNE.csv
# GNPTAB: 195 variants written to clinvar/GNPTAB.csv
# GNPTG: 77 variants written to clinvar/GNPTG.csv
# GPR143: 69 variants written to clinvar/GPR143.csv
# GRHPR: 72 variants written to clinvar/GRHPR.csv
# GRIN1: 113 variants written to clinvar/GRIN1.csv
# GRIN2A: 203 variants written to clinvar/GRIN2A.csv
# GRIN2B: 212 variants written to clinvar/GRIN2B.csv
# GRN: 63 variants written to clinvar/GRN.csv
# GUCY2D: 165 variants written to clinvar/GUCY2D.csv
# GUSB: 69 variants written to clinvar/GUSB.csv
# HADHA: 108 variants written to clinvar/HADHA.csv
# HADHB: 76 variants written to clinvar/HADHB.csv
# HBA2: 65 variants written to clinvar/HBA2.csv
# HBB: 184 variants written to clinvar/HBB.csv
# HDAC8: 76 variants written to clinvar/HDAC8.csv
# HEXA: 213 variants written to clinvar/HEXA.csv
# HEXB: 104 variants written to clinvar/HEXB.csv
# HGD: 203 variants written to clinvar/HGD.csv
# HGSNAT: 115 variants written to clinvar/HGSNAT.csv
# HLCS: 97 variants written to clinvar/HLCS.csv
# HMBS: 107 variants written to clinvar/HMBS.csv
# HMGCL: 64 variants written to clinvar/HMGCL.csv
# HNF1A: 241 variants written to clinvar/HNF1A.csv
# HNF1B: 153 variants written to clinvar/HNF1B.csv
# HNF4A: 130 variants written to clinvar/HNF4A.csv
# HNRNPU: 54 variants written to clinvar/HNRNPU.csv
# HOGA1: 97 variants written to clinvar/HOGA1.csv
# HPRT1: 72 variants written to clinvar/HPRT1.csv
# HPS1: 95 variants written to clinvar/HPS1.csv
# HPS3: 125 variants written to clinvar/HPS3.csv
# HPS4: 56 variants written to clinvar/HPS4.csv
# HPS5: 79 variants written to clinvar/HPS5.csv
# HSD17B3: 52 variants written to clinvar/HSD17B3.csv
# HSD17B4: 145 variants written to clinvar/HSD17B4.csv
# HSD3B2: 62 variants written to clinvar/HSD3B2.csv
# HSPG2: 81 variants written to clinvar/HSPG2.csv
# HUWE1: 74 variants written to clinvar/HUWE1.csv
# IDS: 463 variants written to clinvar/IDS.csv
# IDUA: 250 variants written to clinvar/IDUA.csv
# IFT122: 54 variants written to clinvar/IFT122.csv
# IFT140: 125 variants written to clinvar/IFT140.csv
# IFT172: 97 variants written to clinvar/IFT172.csv
# IGF1R: 50 variants written to clinvar/IGF1R.csv
# IGHMBP2: 98 variants written to clinvar/IGHMBP2.csv
# IL12RB1: 52 variants written to clinvar/IL12RB1.csv
# IL2RG: 113 variants written to clinvar/IL2RG.csv
# IMPG2: 81 variants written to clinvar/IMPG2.csv
# INF2: 57 variants written to clinvar/INF2.csv
# INSR: 58 variants written to clinvar/INSR.csv
# INVS: 66 variants written to clinvar/INVS.csv
# IQCB1: 59 variants written to clinvar/IQCB1.csv
# IQSEC2: 111 variants written to clinvar/IQSEC2.csv
# IRF6: 101 variants written to clinvar/IRF6.csv
# ITGA2B: 166 variants written to clinvar/ITGA2B.csv
# ITGB2: 50 variants written to clinvar/ITGB2.csv
# ITGB3: 128 variants written to clinvar/ITGB3.csv
# ITGB4: 84 variants written to clinvar/ITGB4.csv
# ITPR1: 77 variants written to clinvar/ITPR1.csv
# IVD: 117 variants written to clinvar/IVD.csv
# JAG1: 201 variants written to clinvar/JAG1.csv
# JAK3: 92 variants written to clinvar/JAK3.csv
# KAT6A: 99 variants written to clinvar/KAT6A.csv
# KAT6B: 72 variants written to clinvar/KAT6B.csv
# KCNA2: 55 variants written to clinvar/KCNA2.csv
# KCNB1: 101 variants written to clinvar/KCNB1.csv
# KCNH2: 322 variants written to clinvar/KCNH2.csv
# KCNJ1: 58 variants written to clinvar/KCNJ1.csv
# KCNJ11: 52 variants written to clinvar/KCNJ11.csv
# KCNJ2: 57 variants written to clinvar/KCNJ2.csv
# KCNQ1: 368 variants written to clinvar/KCNQ1.csv
# KCNQ2: 511 variants written to clinvar/KCNQ2.csv
# KCNT1: 75 variants written to clinvar/KCNT1.csv
# KCNV2: 56 variants written to clinvar/KCNV2.csv
# KDM5B: 61 variants written to clinvar/KDM5B.csv
# KDM5C: 122 variants written to clinvar/KDM5C.csv
# KDM6A: 105 variants written to clinvar/KDM6A.csv
# KDM6B: 59 variants written to clinvar/KDM6B.csv
# KIAA0586: 91 variants written to clinvar/KIAA0586.csv
# KIF11: 87 variants written to clinvar/KIF11.csv
# KIF1A: 176 variants written to clinvar/KIF1A.csv
# KIF5A: 75 variants written to clinvar/KIF5A.csv
# KIF7: 60 variants written to clinvar/KIF7.csv
# KIT: 57 variants written to clinvar/KIT.csv
# KMT2A: 246 variants written to clinvar/KMT2A.csv
# KMT2B: 61 variants written to clinvar/KMT2B.csv
# KMT2C: 96 variants written to clinvar/KMT2C.csv
# KMT2D: 497 variants written to clinvar/KMT2D.csv
# KMT2E: 56 variants written to clinvar/KMT2E.csv
# KRAS: 80 variants written to clinvar/KRAS.csv
# KRIT1: 156 variants written to clinvar/KRIT1.csv
# KRT14: 60 variants written to clinvar/KRT14.csv
# KRT5: 83 variants written to clinvar/KRT5.csv
# L1CAM: 148 variants written to clinvar/L1CAM.csv
# LAMA1: 64 variants written to clinvar/LAMA1.csv
# LAMA2: 512 variants written to clinvar/LAMA2.csv
# LAMA3: 166 variants written to clinvar/LAMA3.csv
# LAMB2: 63 variants written to clinvar/LAMB2.csv
# LAMB3: 176 variants written to clinvar/LAMB3.csv
# LAMC2: 123 variants written to clinvar/LAMC2.csv
# LAMC3: 54 variants written to clinvar/LAMC3.csv
# LAMP2: 64 variants written to clinvar/LAMP2.csv
# LCA5: 73 variants written to clinvar/LCA5.csv
# LDLR: 1110 variants written to clinvar/LDLR.csv
# LIFR: 91 variants written to clinvar/LIFR.csv
# LIPA: 106 variants written to clinvar/LIPA.csv
# LMNA: 352 variants written to clinvar/LMNA.csv
# LMX1B: 99 variants written to clinvar/LMX1B.csv
# LOXHD1: 256 variants written to clinvar/LOXHD1.csv
# LPL: 119 variants written to clinvar/LPL.csv
# LRBA: 98 variants written to clinvar/LRBA.csv
# LRP2: 143 variants written to clinvar/LRP2.csv
# LRP5: 137 variants written to clinvar/LRP5.csv
# LRPPRC: 179 variants written to clinvar/LRPPRC.csv
# LRSAM1: 50 variants written to clinvar/LRSAM1.csv
# LYST: 154 variants written to clinvar/LYST.csv
# LZTR1: 350 variants written to clinvar/LZTR1.csv
# MAN2B1: 191 variants written to clinvar/MAN2B1.csv
# MANBA: 70 variants written to clinvar/MANBA.csv
# MBD4: 58 variants written to clinvar/MBD4.csv
# MBD5: 54 variants written to clinvar/MBD5.csv
# MCCC1: 110 variants written to clinvar/MCCC1.csv
# MCCC2: 136 variants written to clinvar/MCCC2.csv
# MCOLN1: 67 variants written to clinvar/MCOLN1.csv
# MCPH1: 62 variants written to clinvar/MCPH1.csv
# MECP2: 225 variants written to clinvar/MECP2.csv
# MED12: 75 variants written to clinvar/MED12.csv
# MED13L: 151 variants written to clinvar/MED13L.csv
# MED17: 49 variants written to clinvar/MED17.csv
# MEF2C: 83 variants written to clinvar/MEF2C.csv
# MEN1: 327 variants written to clinvar/MEN1.csv
# MERTK: 73 variants written to clinvar/MERTK.csv
# MFN2: 163 variants written to clinvar/MFN2.csv
# MFSD8: 96 variants written to clinvar/MFSD8.csv
# MITF: 78 variants written to clinvar/MITF.csv
# MKKS: 55 variants written to clinvar/MKKS.csv
# MKS1: 107 variants written to clinvar/MKS1.csv
# MLC1: 87 variants written to clinvar/MLC1.csv
# MLH1: 654 variants written to clinvar/MLH1.csv
# MMAA: 74 variants written to clinvar/MMAA.csv
# MMAB: 69 variants written to clinvar/MMAB.csv
# MMACHC: 88 variants written to clinvar/MMACHC.csv
# MME: 69 variants written to clinvar/MME.csv
# MMUT: 288 variants written to clinvar/MMUT.csv
# MPDZ: 82 variants written to clinvar/MPDZ.csv
# MPI: 60 variants written to clinvar/MPI.csv
# MPL: 120 variants written to clinvar/MPL.csv
# MPV17: 58 variants written to clinvar/MPV17.csv
# MPZ: 142 variants written to clinvar/MPZ.csv
# MRE11: 99 variants written to clinvar/MRE11.csv
# MSH2: 620 variants written to clinvar/MSH2.csv
# MSH3: 217 variants written to clinvar/MSH3.csv
# MSH6: 523 variants written to clinvar/MSH6.csv
# MTHFR: 130 variants written to clinvar/MTHFR.csv
# MTM1: 174 variants written to clinvar/MTM1.csv
# MTOR: 53 variants written to clinvar/MTOR.csv
# MTR: 61 variants written to clinvar/MTR.csv
# MTRR: 74 variants written to clinvar/MTRR.csv
# MTTP: 93 variants written to clinvar/MTTP.csv
# MUTYH: 215 variants written to clinvar/MUTYH.csv
# MVK: 73 variants written to clinvar/MVK.csv
# MYBPC3: 416 variants written to clinvar/MYBPC3.csv
# MYH11: 53 variants written to clinvar/MYH11.csv
# MYH2: 70 variants written to clinvar/MYH2.csv
# MYH3: 85 variants written to clinvar/MYH3.csv
# MYH7: 407 variants written to clinvar/MYH7.csv
# MYO15A: 405 variants written to clinvar/MYO15A.csv
# MYO18B: 88 variants written to clinvar/MYO18B.csv
# MYO5B: 72 variants written to clinvar/MYO5B.csv
# MYO6: 62 variants written to clinvar/MYO6.csv
# MYO7A: 551 variants written to clinvar/MYO7A.csv
# MYT1L: 72 variants written to clinvar/MYT1L.csv
# NAA15: 101 variants written to clinvar/NAA15.csv
# NAGLU: 184 variants written to clinvar/NAGLU.csv
# NAGS: 63 variants written to clinvar/NAGS.csv
# NALCN: 141 variants written to clinvar/NALCN.csv
# NBAS: 151 variants written to clinvar/NBAS.csv
# NBEA: 64 variants written to clinvar/NBEA.csv
# NBN: 210 variants written to clinvar/NBN.csv
# NDP: 64 variants written to clinvar/NDP.csv
# NDUFAF5: 69 variants written to clinvar/NDUFAF5.csv
# NEB: 914 variants written to clinvar/NEB.csv
# NEK1: 63 variants written to clinvar/NEK1.csv
# NEU1: 54 variants written to clinvar/NEU1.csv
# NEXMIF: 85 variants written to clinvar/NEXMIF.csv
# NF1: 1898 variants written to clinvar/NF1.csv
# NF2: 161 variants written to clinvar/NF2.csv
# NFIX: 87 variants written to clinvar/NFIX.csv
# NFKB1: 71 variants written to clinvar/NFKB1.csv
# NGLY1: 73 variants written to clinvar/NGLY1.csv
# NIPBL: 314 variants written to clinvar/NIPBL.csv
# NKX2-1: 59 variants written to clinvar/NKX2-1.csv
# NKX2-5: 56 variants written to clinvar/NKX2-5.csv
# NLRP3: 64 variants written to clinvar/NLRP3.csv
# NMNAT1: 58 variants written to clinvar/NMNAT1.csv
# NOTCH1: 105 variants written to clinvar/NOTCH1.csv
# NOTCH2: 53 variants written to clinvar/NOTCH2.csv
# NOTCH3: 285 variants written to clinvar/NOTCH3.csv
# NPC1: 372 variants written to clinvar/NPC1.csv
# NPHP1: 75 variants written to clinvar/NPHP1.csv
# NPHP3: 83 variants written to clinvar/NPHP3.csv
# NPHP4: 85 variants written to clinvar/NPHP4.csv
# NPHS1: 267 variants written to clinvar/NPHS1.csv
# NPHS2: 91 variants written to clinvar/NPHS2.csv
# NPR2: 70 variants written to clinvar/NPR2.csv
# NPRL3: 67 variants written to clinvar/NPRL3.csv
# NR0B1: 66 variants written to clinvar/NR0B1.csv
# NR2E3: 74 variants written to clinvar/NR2E3.csv
# NR2F1: 92 variants written to clinvar/NR2F1.csv
# NR5A1: 86 variants written to clinvar/NR5A1.csv
# NSD1: 375 variants written to clinvar/NSD1.csv
# NTHL1: 57 variants written to clinvar/NTHL1.csv
# NTRK1: 116 variants written to clinvar/NTRK1.csv
# OAT: 95 variants written to clinvar/OAT.csv
# OCA2: 199 variants written to clinvar/OCA2.csv
# OCRL: 91 variants written to clinvar/OCRL.csv
# OFD1: 71 variants written to clinvar/OFD1.csv
# OPA1: 213 variants written to clinvar/OPA1.csv
# OPHN1: 51 variants written to clinvar/OPHN1.csv
# OTC: 375 variants written to clinvar/OTC.csv
# OTOF: 252 variants written to clinvar/OTOF.csv
# OTOG: 80 variants written to clinvar/OTOG.csv
# OTOGL: 63 variants written to clinvar/OTOGL.csv
# P3H1: 79 variants written to clinvar/P3H1.csv
# PAFAH1B1: 112 variants written to clinvar/PAFAH1B1.csv
# PAH: 696 variants written to clinvar/PAH.csv
# PALB2: 394 variants written to clinvar/PALB2.csv
# PANK2: 87 variants written to clinvar/PANK2.csv
# PARN: 52 variants written to clinvar/PARN.csv
# PAX2: 86 variants written to clinvar/PAX2.csv
# PAX3: 131 variants written to clinvar/PAX3.csv
# PAX6: 230 variants written to clinvar/PAX6.csv
# PC: 78 variants written to clinvar/PC.csv
# PCARE: 53 variants written to clinvar/PCARE.csv
# PCCA: 174 variants written to clinvar/PCCA.csv
# PCCB: 162 variants written to clinvar/PCCB.csv
# PCDH15: 206 variants written to clinvar/PCDH15.csv
# PCDH19: 229 variants written to clinvar/PCDH19.csv
# PCNT: 189 variants written to clinvar/PCNT.csv
# PDE6A: 80 variants written to clinvar/PDE6A.csv
# PDE6B: 115 variants written to clinvar/PDE6B.csv
# PDE6C: 69 variants written to clinvar/PDE6C.csv
# PDHA1: 211 variants written to clinvar/PDHA1.csv
# PEPD: 60 variants written to clinvar/PEPD.csv
# PEX1: 205 variants written to clinvar/PEX1.csv
# PEX10: 54 variants written to clinvar/PEX10.csv
# PEX6: 128 variants written to clinvar/PEX6.csv
# PEX7: 66 variants written to clinvar/PEX7.csv
# PFKM: 74 variants written to clinvar/PFKM.csv
# PHEX: 463 variants written to clinvar/PHEX.csv
# PHGDH: 56 variants written to clinvar/PHGDH.csv
# PHIP: 111 variants written to clinvar/PHIP.csv
# PHKA2: 84 variants written to clinvar/PHKA2.csv
# PHKB: 81 variants written to clinvar/PHKB.csv
# PIEZO1: 88 variants written to clinvar/PIEZO1.csv
# PIEZO2: 92 variants written to clinvar/PIEZO2.csv
# PIGN: 120 variants written to clinvar/PIGN.csv
# PIK3CA: 89 variants written to clinvar/PIK3CA.csv
# PKD1: 902 variants written to clinvar/PKD1.csv
# PKD2: 189 variants written to clinvar/PKD2.csv
# PKHD1: 796 variants written to clinvar/PKHD1.csv
# PKLR: 94 variants written to clinvar/PKLR.csv
# PKP2: 137 variants written to clinvar/PKP2.csv
# PLA2G6: 124 variants written to clinvar/PLA2G6.csv
# PLEC: 98 variants written to clinvar/PLEC.csv
# PLOD1: 64 variants written to clinvar/PLOD1.csv
# PLP1: 134 variants written to clinvar/PLP1.csv
# PMM2: 174 variants written to clinvar/PMM2.csv
# PMP22: 59 variants written to clinvar/PMP22.csv
# PMS2: 344 variants written to clinvar/PMS2.csv
# PNKP: 59 variants written to clinvar/PNKP.csv
# PNPLA6: 82 variants written to clinvar/PNPLA6.csv
# PNPT1: 49 variants written to clinvar/PNPT1.csv
# POGZ: 84 variants written to clinvar/POGZ.csv
# POLE: 190 variants written to clinvar/POLE.csv
# POLG: 240 variants written to clinvar/POLG.csv
# POLR3A: 96 variants written to clinvar/POLR3A.csv
# POLR3B: 59 variants written to clinvar/POLR3B.csv
# POMGNT1: 139 variants written to clinvar/POMGNT1.csv
# POMT1: 86 variants written to clinvar/POMT1.csv
# POMT2: 86 variants written to clinvar/POMT2.csv
# POR: 49 variants written to clinvar/POR.csv
# POT1: 113 variants written to clinvar/POT1.csv
# POU3F4: 54 variants written to clinvar/POU3F4.csv
# PPT1: 113 variants written to clinvar/PPT1.csv
# PRF1: 95 variants written to clinvar/PRF1.csv
# PRKAR1A: 55 variants written to clinvar/PRKAR1A.csv
# PROC: 97 variants written to clinvar/PROC.csv
# PROM1: 94 variants written to clinvar/PROM1.csv
# PROP1: 63 variants written to clinvar/PROP1.csv
# PROS1: 105 variants written to clinvar/PROS1.csv
# PRPF31: 117 variants written to clinvar/PRPF31.csv
# PRPF8: 49 variants written to clinvar/PRPF8.csv
# PRPH2: 211 variants written to clinvar/PRPH2.csv
# PRRT2: 60 variants written to clinvar/PRRT2.csv
# PSAP: 62 variants written to clinvar/PSAP.csv
# PSEN1: 139 variants written to clinvar/PSEN1.csv
# PTCH1: 323 variants written to clinvar/PTCH1.csv
# PTEN: 515 variants written to clinvar/PTEN.csv
# PTPN11: 159 variants written to clinvar/PTPN11.csv
# PTS: 84 variants written to clinvar/PTS.csv
# PUF60: 54 variants written to clinvar/PUF60.csv
# PURA: 98 variants written to clinvar/PURA.csv
# PYGL: 52 variants written to clinvar/PYGL.csv
# PYGM: 164 variants written to clinvar/PYGM.csv
# RAD50: 210 variants written to clinvar/RAD50.csv
# RAD51C: 136 variants written to clinvar/RAD51C.csv
# RAD51D: 85 variants written to clinvar/RAD51D.csv
# RAF1: 53 variants written to clinvar/RAF1.csv
# RAG1: 103 variants written to clinvar/RAG1.csv
# RAG2: 94 variants written to clinvar/RAG2.csv
# RAI1: 52 variants written to clinvar/RAI1.csv
# RAPSN: 66 variants written to clinvar/RAPSN.csv
# RARS2: 149 variants written to clinvar/RARS2.csv
# RASA1: 119 variants written to clinvar/RASA1.csv
# RB1: 426 variants written to clinvar/RB1.csv
# RBM20: 51 variants written to clinvar/RBM20.csv
# RDH12: 103 variants written to clinvar/RDH12.csv
# RECQL4: 180 variants written to clinvar/RECQL4.csv
# REEP1: 55 variants written to clinvar/REEP1.csv
# RELN: 71 variants written to clinvar/RELN.csv
# RET: 117 variants written to clinvar/RET.csv
# RHO: 173 variants written to clinvar/RHO.csv
# RP1: 128 variants written to clinvar/RP1.csv
# RP2: 68 variants written to clinvar/RP2.csv
# RPE65: 232 variants written to clinvar/RPE65.csv
# RPGR: 326 variants written to clinvar/RPGR.csv
# RPGRIP1: 93 variants written to clinvar/RPGRIP1.csv
# RPGRIP1L: 178 variants written to clinvar/RPGRIP1L.csv
# RPS19: 51 variants written to clinvar/RPS19.csv
# RPS6KA3: 100 variants written to clinvar/RPS6KA3.csv
# RS1: 221 variants written to clinvar/RS1.csv
# RTEL1: 161 variants written to clinvar/RTEL1.csv
# RTTN: 61 variants written to clinvar/RTTN.csv
# RUNX1: 97 variants written to clinvar/RUNX1.csv
# RUNX2: 93 variants written to clinvar/RUNX2.csv
# RYR1: 490 variants written to clinvar/RYR1.csv
# RYR2: 239 variants written to clinvar/RYR2.csv
# SACS: 350 variants written to clinvar/SACS.csv
# SAMHD1: 73 variants written to clinvar/SAMHD1.csv
# SATB2: 117 variants written to clinvar/SATB2.csv
# SBF2: 57 variants written to clinvar/SBF2.csv
# SCN1A: 1488 variants written to clinvar/SCN1A.csv
# SCN2A: 547 variants written to clinvar/SCN2A.csv
# SCN4A: 137 variants written to clinvar/SCN4A.csv
# SCN5A: 326 variants written to clinvar/SCN5A.csv
# SCN8A: 324 variants written to clinvar/SCN8A.csv
# SCN9A: 114 variants written to clinvar/SCN9A.csv
# SDCCAG8: 54 variants written to clinvar/SDCCAG8.csv
# SDHA: 165 variants written to clinvar/SDHA.csv
# SDHB: 159 variants written to clinvar/SDHB.csv
# SDHC: 58 variants written to clinvar/SDHC.csv
# SDHD: 77 variants written to clinvar/SDHD.csv
# SEC23B: 62 variants written to clinvar/SEC23B.csv
# SELENON: 58 variants written to clinvar/SELENON.csv
# SEPSECS: 52 variants written to clinvar/SEPSECS.csv
# SERPINC1: 102 variants written to clinvar/SERPINC1.csv
# SERPING1: 202 variants written to clinvar/SERPING1.csv
# SETBP1: 63 variants written to clinvar/SETBP1.csv
# SETD5: 127 variants written to clinvar/SETD5.csv
# SETX: 54 variants written to clinvar/SETX.csv
# SGCA: 122 variants written to clinvar/SGCA.csv
# SGCB: 56 variants written to clinvar/SGCB.csv
# SGCE: 69 variants written to clinvar/SGCE.csv
# SGCG: 56 variants written to clinvar/SGCG.csv
# SGSH: 126 variants written to clinvar/SGSH.csv
# SH3TC2: 96 variants written to clinvar/SH3TC2.csv
# SHANK3: 64 variants written to clinvar/SHANK3.csv
# SHH: 90 variants written to clinvar/SHH.csv
# SHOX: 84 variants written to clinvar/SHOX.csv
# SI: 103 variants written to clinvar/SI.csv
# SIN3A: 57 variants written to clinvar/SIN3A.csv
# SKIC2: 71 variants written to clinvar/SKIC2.csv
# SKIC3: 93 variants written to clinvar/SKIC3.csv
# SLC12A1: 92 variants written to clinvar/SLC12A1.csv
# SLC12A3: 308 variants written to clinvar/SLC12A3.csv
# SLC12A6: 117 variants written to clinvar/SLC12A6.csv
# SLC16A2: 69 variants written to clinvar/SLC16A2.csv
# SLC17A5: 78 variants written to clinvar/SLC17A5.csv
# SLC20A2: 54 variants written to clinvar/SLC20A2.csv
# SLC22A5: 195 variants written to clinvar/SLC22A5.csv
# SLC25A13: 118 variants written to clinvar/SLC25A13.csv
# SLC26A2: 88 variants written to clinvar/SLC26A2.csv
# SLC26A3: 74 variants written to clinvar/SLC26A3.csv
# SLC26A4: 437 variants written to clinvar/SLC26A4.csv
# SLC2A1: 201 variants written to clinvar/SLC2A1.csv
# SLC34A3: 58 variants written to clinvar/SLC34A3.csv
# SLC37A4: 90 variants written to clinvar/SLC37A4.csv
# SLC39A4: 59 variants written to clinvar/SLC39A4.csv
# SLC3A1: 100 variants written to clinvar/SLC3A1.csv
# SLC45A2: 68 variants written to clinvar/SLC45A2.csv
# SLC4A1: 118 variants written to clinvar/SLC4A1.csv
# SLC4A11: 97 variants written to clinvar/SLC4A11.csv
# SLC6A1: 141 variants written to clinvar/SLC6A1.csv
# SLC6A8: 92 variants written to clinvar/SLC6A8.csv
# SLC7A7: 67 variants written to clinvar/SLC7A7.csv
# SLC7A9: 54 variants written to clinvar/SLC7A9.csv
# SLX4: 72 variants written to clinvar/SLX4.csv
# SMAD3: 105 variants written to clinvar/SMAD3.csv
# SMAD4: 128 variants written to clinvar/SMAD4.csv
# SMARCA2: 120 variants written to clinvar/SMARCA2.csv
# SMARCA4: 208 variants written to clinvar/SMARCA4.csv
# SMARCAL1: 85 variants written to clinvar/SMARCAL1.csv
# SMARCB1: 68 variants written to clinvar/SMARCB1.csv
# SMC1A: 140 variants written to clinvar/SMC1A.csv
# SMC3: 64 variants written to clinvar/SMC3.csv
# SMCHD1: 84 variants written to clinvar/SMCHD1.csv
# SMPD1: 225 variants written to clinvar/SMPD1.csv
# SOD1: 126 variants written to clinvar/SOD1.csv
# SOS1: 67 variants written to clinvar/SOS1.csv
# SOX10: 119 variants written to clinvar/SOX10.csv
# SOX11: 74 variants written to clinvar/SOX11.csv
# SOX5: 59 variants written to clinvar/SOX5.csv
# SOX9: 84 variants written to clinvar/SOX9.csv
# SPAST: 354 variants written to clinvar/SPAST.csv
# SPG11: 236 variants written to clinvar/SPG11.csv
# SPG7: 99 variants written to clinvar/SPG7.csv
# SPINK5: 72 variants written to clinvar/SPINK5.csv
# SPRED1: 70 variants written to clinvar/SPRED1.csv
# SPTA1: 152 variants written to clinvar/SPTA1.csv
# SPTAN1: 80 variants written to clinvar/SPTAN1.csv
# SPTB: 286 variants written to clinvar/SPTB.csv
# SRD5A2: 71 variants written to clinvar/SRD5A2.csv
# STAR: 57 variants written to clinvar/STAR.csv
# STAT1: 85 variants written to clinvar/STAT1.csv
# STAT3: 97 variants written to clinvar/STAT3.csv
# STK11: 160 variants written to clinvar/STK11.csv
# STXBP1: 274 variants written to clinvar/STXBP1.csv
# STXBP2: 65 variants written to clinvar/STXBP2.csv
# SUFU: 53 variants written to clinvar/SUFU.csv
# SUMF1: 92 variants written to clinvar/SUMF1.csv
# SURF1: 81 variants written to clinvar/SURF1.csv
# SYNE1: 238 variants written to clinvar/SYNE1.csv
# SYNGAP1: 209 variants written to clinvar/SYNGAP1.csv
# SZT2: 112 variants written to clinvar/SZT2.csv
# TAFAZZIN: 65 variants written to clinvar/TAFAZZIN.csv
# TAOK1: 59 variants written to clinvar/TAOK1.csv
# TBC1D24: 73 variants written to clinvar/TBC1D24.csv
# TBCD: 61 variants written to clinvar/TBCD.csv
# TBCK: 55 variants written to clinvar/TBCK.csv
# TBL1XR1: 87 variants written to clinvar/TBL1XR1.csv
# TBX5: 109 variants written to clinvar/TBX5.csv
# TCF12: 67 variants written to clinvar/TCF12.csv
# TCF20: 51 variants written to clinvar/TCF20.csv
# TCF4: 154 variants written to clinvar/TCF4.csv
# TCIRG1: 137 variants written to clinvar/TCIRG1.csv
# TCOF1: 67 variants written to clinvar/TCOF1.csv
# TECPR2: 52 variants written to clinvar/TECPR2.csv
# TECTA: 79 variants written to clinvar/TECTA.csv
# TERT: 98 variants written to clinvar/TERT.csv
# TET2: 63 variants written to clinvar/TET2.csv
# TFR2: 86 variants written to clinvar/TFR2.csv
# TG: 165 variants written to clinvar/TG.csv
# TGFB2: 55 variants written to clinvar/TGFB2.csv
# TGFBR1: 80 variants written to clinvar/TGFBR1.csv
# TGFBR2: 120 variants written to clinvar/TGFBR2.csv
# TGM1: 189 variants written to clinvar/TGM1.csv
# TH: 114 variants written to clinvar/TH.csv
# THRB: 69 variants written to clinvar/THRB.csv
# TJP2: 49 variants written to clinvar/TJP2.csv
# TK2: 63 variants written to clinvar/TK2.csv
# TLK2: 68 variants written to clinvar/TLK2.csv
# TMC1: 119 variants written to clinvar/TMC1.csv
# TMEM67: 163 variants written to clinvar/TMEM67.csv
# TMPRSS3: 98 variants written to clinvar/TMPRSS3.csv
# TNNI3: 74 variants written to clinvar/TNNI3.csv
# TNNT2: 59 variants written to clinvar/TNNT2.csv
# TNXB: 57 variants written to clinvar/TNXB.csv
# TP53: 420 variants written to clinvar/TP53.csv
# TP63: 104 variants written to clinvar/TP63.csv
# TPM1: 51 variants written to clinvar/TPM1.csv
# TPO: 73 variants written to clinvar/TPO.csv
# TPP1: 131 variants written to clinvar/TPP1.csv
# TRIM37: 65 variants written to clinvar/TRIM37.csv
# TRIO: 107 variants written to clinvar/TRIO.csv
# TRIOBP: 51 variants written to clinvar/TRIOBP.csv
# TRMU: 82 variants written to clinvar/TRMU.csv
# TRPM1: 73 variants written to clinvar/TRPM1.csv
# TRPS1: 87 variants written to clinvar/TRPS1.csv
# TRPV4: 64 variants written to clinvar/TRPV4.csv
# TSC1: 282 variants written to clinvar/TSC1.csv
# TSC2: 688 variants written to clinvar/TSC2.csv
# TSHR: 80 variants written to clinvar/TSHR.csv
# TTC21B: 81 variants written to clinvar/TTC21B.csv
# TTC7A: 55 variants written to clinvar/TTC7A.csv
# TTLL5: 52 variants written to clinvar/TTLL5.csv
# TTN: 2363 variants written to clinvar/TTN.csv
# TTR: 129 variants written to clinvar/TTR.csv
# TUBA1A: 193 variants written to clinvar/TUBA1A.csv
# TUBB2B: 72 variants written to clinvar/TUBB2B.csv
# TUBB3: 56 variants written to clinvar/TUBB3.csv
# TUBGCP6: 61 variants written to clinvar/TUBGCP6.csv
# TULP1: 93 variants written to clinvar/TULP1.csv
# TWIST1: 59 variants written to clinvar/TWIST1.csv
# TWNK: 64 variants written to clinvar/TWNK.csv
# TYMP: 118 variants written to clinvar/TYMP.csv
# TYR: 237 variants written to clinvar/TYR.csv
# TYRP1: 50 variants written to clinvar/TYRP1.csv
# UBE3A: 116 variants written to clinvar/UBE3A.csv
# UBR1: 49 variants written to clinvar/UBR1.csv
# UMOD: 101 variants written to clinvar/UMOD.csv
# UNC13D: 111 variants written to clinvar/UNC13D.csv
# UNC80: 104 variants written to clinvar/UNC80.csv
# USH1C: 112 variants written to clinvar/USH1C.csv
# USH2A: 1200 variants written to clinvar/USH2A.csv
# USP9X: 77 variants written to clinvar/USP9X.csv
# VCP: 51 variants written to clinvar/VCP.csv
# VHL: 236 variants written to clinvar/VHL.csv
# VPS13A: 260 variants written to clinvar/VPS13A.csv
# VPS13B: 475 variants written to clinvar/VPS13B.csv
# VPS13C: 61 variants written to clinvar/VPS13C.csv
# VPS13D: 54 variants written to clinvar/VPS13D.csv
# VWF: 313 variants written to clinvar/VWF.csv
# WAS: 115 variants written to clinvar/WAS.csv
# WDFY3: 62 variants written to clinvar/WDFY3.csv
# WDR19: 100 variants written to clinvar/WDR19.csv
# WDR45: 107 variants written to clinvar/WDR45.csv
# WDR62: 68 variants written to clinvar/WDR62.csv
# WFS1: 153 variants written to clinvar/WFS1.csv
# WNT10A: 66 variants written to clinvar/WNT10A.csv
# WRN: 220 variants written to clinvar/WRN.csv
# WT1: 103 variants written to clinvar/WT1.csv
# WWOX: 62 variants written to clinvar/WWOX.csv
# XPC: 108 variants written to clinvar/XPC.csv
# ZBTB20: 66 variants written to clinvar/ZBTB20.csv
# ZEB2: 161 variants written to clinvar/ZEB2.csv
# ZFYVE26: 217 variants written to clinvar/ZFYVE26.csv
# ZNF469: 52 variants written to clinvar/ZNF469.csv

# %%
terms = ["Pathogenic", "Likely pathogenic", "Pathogenic/Likely pathogenic", "Pathogenic, low penetrance", "Likely pathogenic, low penetrance"]

for gene in lociii:
    filtered = Clin1[
        (Clin1["GeneSymbol"] == gene) &
        (Clin1["ClinicalSignificance"].isin(terms)) &
        (Clin1["Type"] == "single nucleotide variant") &
        (Clin1["Assembly"] == "GRCh38")
    ]

    print(gene, len(filtered))
# Out:
# - 16
# A4GALT 1
# AAAS 66
# AASS 16
# ABCA12 134
# ABCC11 0
# ABCG5 46
# ABCG5;ABCG8 0
# ABCG8 43
# ABHD12 30
# ABHD5 22
# ACAD8 32
# ACAD9 103
# ACADL 0
# ACADM 253
# ACADS 59
# ACADVL 286
# ACAT1 119
# ACOX1 45
# ACTN4 15
# ADA 106
# ADA;PKIG 1
# ADAMTS10 27
# ADAMTS13 81
# ADAMTS17 43
# ADAMTS2 49
# ADAMTSL2 20
# ADAMTSL4 68
# ADCY10 21
# ADGRG1 74
# ADIPOQ 1
# ADSL 62
# AFG3L2 55
# AGA 68
# AGL 307
# AGXT 232
# AHI1 134
# AICDA 30
# AIP 36
# AIPL1 52
# AIRE 120
# AKAP10 0
# AKAP9 3
# AKR1D1 18
# ALDH3A2 94
# ALDH4A1 10
# ALDH5A1 89
# ALDOB 84
# ALG1 86
# ALG12 23
# ALG2 6
# ALG3 29
# ALG6 77
# ALG8 39
# ALG9 25
# ALMS1 435
# ALOX12B 104
# ALOXE3 46
# ALS2 77
# ALX3 8
# ALX4 9
# AMACR 2
# AMN 32
# ANGPTL4 0
# ANK1 222
# ANKH 9
# ANKH;ANKH-DT 1
# ANKK1 0
# ANO5 127
# ANTXR1 7
# ANTXR2 21
# AP5Z1 32
# APBB1;SMPD1 1
# APC 764
# APCDD1 1
# APOA5 8
# APOC2 12
# APOC4-APOC2;APOC2 0
# APOL1 0
# APTX 24
# AREL1;MLH3 0
# ARFGEF2 16
# ARG1 67
# ARHGAP26 0
# ARHGAP9 0
# ARHGEF10 0
# ARL13B 21
# ARL6 41
# ARMS2 0
# ARSA 263
# ARSB 166
# ASAH1 90
# ASL 176
# ASPA 112
# ASPM 151
# ASPN;CENPP 0
# ATG16L1 0
# ATL1 82
# ATM 1343
# ATP13A2 46
# ATP2C1 33
# ATP6V0A2 41
# ATP6V0A4 53
# ATP7B 424
# ATPAF2 2
# ATXN10 0
# ATXN3 0
# ATXN7 2
# ATXN8;ATXN8OS;LOC109461478 0
# AXIN1 2
# AXIN2 67
# B3GLCT 15
# B4GALT7 11
# BAG3 65
# BANK1 0
# BBS10 88
# BBS12 58
# BBS2 133
# BBS7 70
# BBS9 93
# BCAM 3
# BCKDHA 113
# BCO1 0
# BEAN1 0
# BEST1 278
# BHLHE41 0
# BLM 221
# BLNK 11
# BLOC1S3 1
# BRIP1 326
# BSCL2 31
# BSCL2;HNRNPUL2-BSCL2 1
# BSND 26
# BTD 161
# BTNL2 0
# C1QTNF5 6
# CA2 16
# CABP4 16
# CACNA1H 8
# CACNA2D4 3
# CANT1 29
# CAPN10 2
# CARD14;SGSH 1
# CARD9 14
# CASP12 0
# CATSPER1 1
# CBLIF 8
# CBS 197
# CC2D1A 35
# CC2D2A 194
# CCBE1 13
# CCDC28B 0
# CCDC50 1
# CCM2 50
# CCT5 1
# CD207 0
# CD209 0
# CD244 0
# CD2AP 7
# CD96 4
# CDAN1 26
# CDC73 72
# CDH23 382
# CDK5RAP2 47
# CDKAL1 0
# CEP152 76
# CEP290 463
# CERKL 104
# CFC1 1
# CFHR1;CFHR3 0
# CHD7 426
# CHEK2 295
# CHMP2B 6
# CHMP4B 3
# CHST14 15
# CHST3 36
# CHST6 36
# CILK1 5
# CISD2 3
# CLCF1 4
# CLDN1 5
# CLDN14 10
# CLDN16 41
# CLDN19 22
# CLEC7A 0
# CLN3 127
# CLN5 67
# CLN6 68
# CLN8 58
# CLRN1 54
# CLRN1-AS1;CLRN1 1
# CNGB3 147
# CNNM4 28
# CNTNAP2 55
# COG1 9
# COG4 24
# COG5 42
# COG7 21
# COG8 9
# COQ2 24
# COQ8A 56
# COQ9 17
# COX4I2 0
# CPAP 38
# CPOX 23
# CPS1 262
# CRB1 357
# CRBN 8
# CRELD1 8
# CRLF1 16
# CRTAP 33
# CST3 1
# CTDP1 1
# CTH 2
# CTNS 113
# CTSA 46
# CUL7 68
# CYB5A 3
# CYB5R3 30
# CYBA 44
# CYLD 35
# CYP11B1 126
# CYP17A1 107
# CYP27A1 124
# CYP27B1 57
# CYP2R1 19
# CYP3A5 0
# CYP4F22 41
# CYP4V2 57
# CYP7B1 45
# D2HGDH 20
# DARS2 47
# DBH 6
# DCAF17 29
# DCLRE1C 103
# DDX25;HYLS1;PUS3 1
# DHCR24 6
# DHH 14
# DICER1 326
# DIP2B 1
# DISC1 0
# DLAT 11
# DLC1 1
# DMGDH 2
# DMPK 0
# DNAAF1 31
# DNAAF2 23
# DNAAF4 17
# DNAI1 93
# DNAI2 58
# DNAJC19 9
# DNM1L 48
# DOCK8 61
# DOK7 60
# DOLK 12
# DPM3 10
# DPYD 82
# DPYS 23
# DSG4 10
# DTNBP1 7
# DUOX2 145
# DUOXA2 17
# DYM 35
# EDAR 64
# EDARADD 15
# EFEMP2 24
# EFHC1 0
# EGLN1 7
# EHBP1 0
# EHMT1 129
# EIF2AK3 56
# EIF2B1 19
# EIF2B2 23
# EIF2B3 14
# EIF2B4 26
# EIF2B5 91
# ELAC2 53
# ELOVL4 13
# ELP1 229
# EMG1 1
# ENAM 8
# EPM2A 33
# ERCC6 178
# ERCC8 80
# ERCC8;NDUFAF2 3
# ERMAP 0
# ESCO2 56
# ESPN 13
# ETFA 41
# ETHE1 53
# EVC 149
# EVC2 173
# EXT1 242
# EXT2 115
# EYS 483
# F12 15
# F5 64
# FA2H 41
# FAM161A 77
# FAM20C 21
# FANCA 528
# FANCI 141
# FANCI;POLG 1
# FANCL 62
# FANCM 87
# FASTKD2 18
# FBLN5 6
# FBN2 116
# FBP1 32
# FBXO7 26
# FCGR2B 0
# FCN3 0
# FECH 54
# FERMT1 30
# FERMT3 12
# FGD4 21
# FGF20 1
# FGF23 12
# FIG4 74
# FIGLA 4
# FKBP10 33
# FKRP 119
# FKTN 87
# FLCN 156
# FLVCR2 13
# FOXD3 0
# FOXL2 66
# FOXP2 40
# FOXRED1 44
# FRAS1 180
# FREM1 46
# FREM2 54
# FRZB 0
# FSCN2 2
# FTCD 14
# FTO 3
# FUCA1 55
# FXN 15
# FZD4 39
# G6PC3 33
# GAA 451
# GABBR2 16
# GAD1 13
# GALC 233
# GALE 32
# GALK1 57
# GALNS 222
# GALNT12 0
# GALT 247
# GAN 39
# GBA1 293
# GBE1 121
# GCDH 257
# GCDH;KLF1;LOC117125594 1
# GCLC 2
# GCM2 15
# GDAP1 62
# GFM1 99
# GHRL 0
# GIGYF2 0
# GJB4 6
# GJB6 8
# GJC2 36
# GLB1 229
# GLIS3 10
# GLRX5 7
# GM2A 10
# GNAS;GNAS-AS1 1
# GNE 137
# GNMT 2
# GNPTAB 195
# GNPTG 77
# GNS 40
# GORAB 23
# GP1BA 43
# GPC6 2
# GPD1L 0
# GPHN 27
# GPSM2 20
# GRHL2 18
# GRHPR 70
# GRM6 34
# GRXCR1 13
# GSDME 5
# GTF2H5 8
# GUSB 67
# GYG1 20
# HABP2 0
# HAL 0
# HAMP 6
# HAVCR1 0
# HAX1 30
# HCN4 17
# HDAC4 9
# HERC2 15
# HEXA 207
# HEXB 103
# HFE 30
# HGD 203
# HGSNAT 113
# HIBCH 30
# HJV 43
# HLCS 97
# HMBS 108
# HMCN1 0
# HNMT 2
# HOGA1 97
# HOXA2 4
# HPD 20
# HPS1 92
# HPS1;MIR4685 0
# HPS3 122
# HPS4 51
# HPS5 76
# HPS6 39
# HPSE2 12
# HSD17B3 49
# HSD3B7 14
# HSPB3 0
# HSPB8 7
# HTRA2 6
# HTRA2;LOXL3 0
# HTT 5
# HYAL1 21
# HYCC1 13
# ICOS 6
# IDH3B 16
# IFT122 54
# IFT80 35
# IGF2BP2 0
# IL23R 0
# IMPG2 80
# INF2 55
# INPP5E 45
# IQCB1 55
# IRAK3 0
# IRAK4 16
# IRF5 1
# IRF6 99
# ISCU 2
# ITCH 11
# ITGA2B 165
# ITM2B 3
# ITPKC 0
# IVD 107
# IYD 5
# JPH3 0
# KALRN 0
# KANK1 1
# KCNE2 1
# KCNE3 0
# KCNE3;LIPT2 0
# KCNJ18 0
# KCNK9 8
# KCNMB1 0
# KCNQ1 365
# KCNQ1OT1 0
# KCNV2 54
# KCTD7 24
# KIF1B 2
# KIF21A 14
# KIFBP 7
# KIRREL3 3
# KISS1R 11
# KL 0
# KLHDC8B 0
# KLHL7 29
# KLK4 4
# KNG1 8
# KRIT1 156
# KRT74 3
# KRT75 0
# KRT9 19
# L2HGDH 33
# LAMTOR2 0
# LCA5 73
# LCAT 29
# LDB3 19
# LDLR 1093
# LDLR;MIR6886 2
# LDLRAP1 34
# LEMD3 32
# LGI1 45
# LHFPL5 15
# LIPA 102
# LIPH 5
# LIPI 0
# LITAF 8
# LLGL2;TSEN54 1
# LMBR1 3
# LMBR1;ZRS 5
# LMBRD1 30
# LMF1 17
# LOXHD1 253
# LPAR6 11
# LPIN1 23
# LPIN2 23
# LPL 115
# LPO;MPO 1
# LRAT 14
# LRP4 38
# LRPPRC 169
# LRRK2 9
# LRTOMT 17
# LTBP4 41
# LYST 150
# LZTS1 2
# MAN2B1 187
# MANBA 68
# MAPK8IP1 0
# MARVELD2 17
# MASP2 2
# MASTL 0
# MAT1A 33
# MBD5 53
# MC2R 23
# MCCC1 107
# MCCC2 133
# MCEE 4
# MCFD2 7
# MCOLN1 67
# MCPH1 62
# MED13L 149
# MED25 5
# MEFV 16
# MERTK 73
# MESP2 33
# MFN2 162
# MFRP 34
# MFSD8 95
# MIAT 0
# MINPP1 9
# MIR103A2;MIR103B2;PANK2 1
# MIR2861 0
# MIR96 2
# MKKS 55
# MKS1 107
# MLC1 86
# MLH3 1
# MLPH 7
# MLYCD 31
# MMAA 72
# MMAB 67
# MMACHC 88
# MMADHC 36
# MMP20 10
# MMUT 288
# MOCS2 25
# MPDU1 11
# MPLKIP 8
# MPO 11
# MRAP 6
# MRPS16 0
# MRPS22 12
# MSH2 614
# MTHFR 130
# MTMR14 0
# MTRFR 7
# MUTYH 212
# MYH14 17
# MYLK2 0
# MYO3A 45
# MYO5B 72
# MYOT 8
# NAGLU 183
# NAGS 62
# NAT2 0
# NCF1 8
# NCF2 45
# NCR3 1
# NDRG1 35
# NDUFA13 4
# NDUFAF2 6
# NDUFAF3 7
# NDUFAF4 1
# NDUFAF5 68
# NDUFAF6 20
# NDUFS3 5
# NDUFS6 19
# NECTIN4 10
# NEK8 23
# NEU1 50
# NEUROG3 10
# NEXN 11
# NF1 1881
# NF2 161
# NHEJ1 24
# NHERF1 0
# NHLRC1 26
# NHP2 3
# NIPA1 4
# NIPAL4 29
# NIPBL 309
# NKX2-6 2
# NLRP1 5
# NLRP12 6
# NLRP3 63
# NLRP7 18
# NME8 0
# NOBOX 8
# NOD2 21
# NOP10 1
# NPC1 361
# NPC1L1 0
# NPHP1 74
# NPHP3 82
# NPHP4 84
# NPHS2 88
# NPSR1 0
# NR0B2 2
# NR2E3 73
# NSD1 365
# NSMF 2
# NT5C3A 11
# NUBPL 13
# NUP62 1
# OAT 91
# OBSL1 31
# OCA2 199
# OPA1 210
# OPA3 21
# OPN1SW 0
# ORAI1 11
# OSTM1 17
# OTOA 44
# P3H1 79
# PAH 689
# PALB2 391
# PALLD 0
# PANK2 85
# PAX3 126
# PAX6 227
# PC 78
# PCARE 53
# PCDH15 205
# PCNT 188
# PCSK9 17
# PDCD10 37
# PDE11A 6
# PDGFRL 1
# PDHX 19
# PDP1 2
# PDSS1 10
# PDSS2 3
# PEPD 55
# PEX26 31
# PFKM 70
# PGAM2 7
# PHGDH 56
# PHOX2B 22
# PIGM 1
# PIGV 8
# PIKFYVE 16
# PINK1 27
# PIP5K1C 5
# PITPNM3 2
# PJVK 23
# PKHD1 786
# PKLR 94
# PLCE1 34
# PLEKHG4 0
# PLEKHG5 42
# PLEKHM1 3
# PNKD 3
# PNKP 57
# PNPLA2 19
# POLG2 17
# POLH 30
# POMGNT1 139
# POMP 0
# POMT1 86
# POMT2 86
# POU6F2 2
# PPARGC1B 0
# PPP1R17 0
# PPP2R2B 0
# PRCD 8
# PRG4 8
# PRICKLE1 2
# PRKAG3 0
# PRKCH 0
# PROC 96
# PRODH 11
# PROK2 6
# PROKR2 8
# PROM1 94
# PRPF3 11
# PRPF31 117
# PRPF8 49
# PRSS12 2
# PRX 33
# PSAT1 21
# PSTPIP1 4
# PTF1A 3
# PTGDR 0
# PTS 82
# PUS1 33
# PYGM 157
# QDPR 48
# RAB23 17
# RAB27A 31
# RAB3GAP2 27
# RAD50 210
# RAD54B 1
# RAI1 50
# RARS2 140
# RAX2 4
# RB1CC1 1
# RBBP8 7
# RBM20 52
# RBM28 2
# RDH12 100
# RECQL4 180
# REEP1 55
# RETN 0
# RETREG1 15
# RFT1 14
# RFX6 25
# RGS9 28
# RGS9BP 1
# RIMS1 2
# RIN2 6
# RNASEH2A 29
# RNASEH2B 37
# RNASEH2C 6
# RNASET2 7
# RNF135 0
# RNF168 10
# RNF212 0
# RNF6 3
# ROBO3 27
# RP1 129
# RP1L1 36
# RP9 1
# RPGRIP1 93
# RPGRIP1L 178
# RPL11 18
# RRM2B 32
# RSPH4A 33
# RSPO1 3
# RSPO4 9
# RTN4R 0
# RXFP2 1
# SACK1H 16
# SACS 339
# SALL4 16
# SAMD9 30
# SAMHD1 73
# SAR1B 13
# SART3 8
# SATB2 117
# SBDS 25
# SBF2 57
# SCGB3A2 0
# SCN3B 2
# SCN4A 135
# SCN4B 2
# SCO2 19
# SDCCAG8 53
# SDHAF1 8
# SDHAF2 23
# SEC23A 3
# SEC23B 62
# SEC63 34
# SECISBP2 10
# SELENON 57
# SEMA3E 0
# SEMA4A 3
# SEPTIN9 3
# SERPINA10 0
# SERPINF2 2
# SERPING1 201
# SETBP1 61
# SETX 54
# SGCE 69
# SGCG 55
# SGSH 124
# SGSH;SLC26A11 1
# SH3PXD2B 10
# SH3TC2 95
# SI 103
# SIAE 0
# SIL1 17
# SIX3 18
# SIX6 5
# SLC12A6 116
# SLC16A12 2
# SLC17A5 78
# SLC17A8 3
# SLC19A2 36
# SLC19A3 48
# SLC22A12 16
# SLC22A4 0
# SLC24A4 5
# SLC24A5 26
# SLC25A13 118
# SLC25A15 43
# SLC25A19 14
# SLC25A22 15
# SLC25A38 37
# SLC26A2 86
# SLC26A4 438
# SLC26A5 13
# SLC27A4 35
# SLC29A3 26
# SLC2A10 33
# SLC2A9 13
# SLC30A8 0
# SLC34A2 10
# SLC34A3 58
# SLC35A1 4
# SLC35C1 7
# SLC35D1 10
# SLC36A2 0
# SLC39A13 1
# SLC39A4 58
# SLC40A1 38
# SLC45A2 68
# SLC46A1 10
# SLC4A11 97
# SLC52A3 21
# SLC6A19 34
# SLC6A20 0
# SLC6A5 48
# SLC7A9 54
# SLC9A9 1
# SLITRK1 1
# SLURP1 12
# SMARCAL1 81
# SMC3 63
# SMPD1 225
# SNCAIP 0
# SOST 6
# SOX9 84
# SP110 20
# SPART 11
# SPAST 354
# SPATA16 0
# SPATA7 29
# SPG11 236
# SPG21 6
# SPINK5 71
# SPINT2 15
# SPRED1 69
# SPTBN2 43
# SPTLC1 12
# SPTLC2 10
# SRD5A2 71
# ST14 10
# ST3GAL5 28
# STAT5B 18
# STIM1 26
# STOX1 0
# STRA6 17
# STRADA 14
# STRC 42
# STX11 13
# SUCLA2 23
# SUFU 52
# SUGCT 4
# SUMF1 89
# SUMF2 0
# SUMO4;TAB2 0
# SUOX 39
# SYCP3 1
# SYNE1 235
# SYNE2 4
# TAB2 33
# TACO1 8
# TARDBP 24
# TAS2R16 0
# TAS2R38 0
# TAT 40
# TBC1D24 73
# TBCE 32
# TBX15 1
# TBX19 20
# TBX20 25
# TBX21 0
# TCAP 15
# TCIRG1 135
# TCN2 29
# TCOF1 65
# TDP1 5
# TFR2 87
# TGM5 13
# THAP1 25
# TINF2 18
# TIRAP 0
# TJP2 49
# TLL1 3
# TMC1 118
# TMC6 19
# TMC8 15
# TMEM126A 4
# TMEM127 44
# TMEM216 28
# TMEM43 2
# TMEM67 162
# TMEM70 14
# TMIE 11
# TMPRSS15 47
# TMPRSS3 97
# TMPRSS6 22
# TNFRSF13B 19
# TNFRSF13C 1
# TOPORS 5
# TOR1A 11
# TPCN2 1
# TPH2 0
# TPO 73
# TPP1 131
# TPRN 6
# TRAPPC9 45
# TREM2 17
# TREX1 18
# TRIM37 65
# TRIOBP 51
# TRIP11 44
# TRMU 80
# TRPM4 7
# TRPM6 38
# TRPM7 4
# TRPS1 86
# TRPV4 64
# TSC1 281
# TSEN2 17
# TSEN34 1
# TSEN54 42
# TSFM 40
# TSPAN12 25
# TSPYL1 0
# TTBK2 3
# TTC8 42
# TUBA8 1
# TUBB1 12
# TUBB2B 72
# TWNK 64
# TYR 237
# TYROBP 5
# UBIAD1 12
# UBR1 49
# UNC119 1
# UNC13D 105
# UNC93B1 7
# UPB1 12
# UPK3A 1
# UQCRQ 0
# UROC1 3
# UROD 37
# UROS 27
# USB1 14
# USH1C 112
# USH1G 21
# USH2A 1202
# UTP4 0
# VANGL1 1
# VAPB 2
# VHL 235
# VIPAS39 23
# VKORC1 5
# VPS13A 242
# VPS13B 474
# VPS33B 38
# VSX1 0
# VWF 310
# WASHC5 30
# WDPCP 28
# WDR35 48
# WDR36 0
# WDR62 64
# WDR72 25
# WFS1 154
# WHRN 25
# WNK1 34
# WNT10A 66
# WRN 220
# WT1 102
# WWC1 0
# WWOX 63
# XDH 33
# XPA 45
# XPC 108
# XPNPEP3 13
# XYLT1 13
# XYLT2 4
# YARS2 18
# ZEB2 159
# ZFAT 0
# ZFP57 6
# ZFYVE26 211
# ZFYVE27 0
# ZMPSTE24 22
# ZNF365 0
# ZNF469 51
# ZNF513 0
# ZNF592 0
# ZNF750 0
# ZRS;LMBR1 4

# %%
variant_counts = Clin1["GeneSymbol"].value_counts().sort_index().reset_index()
variant_counts.columns = ["GeneSymbol", "Number of Variants"]
#print(variant_counts)
variant_counts.head(20)
# Out:
#                                            GeneSymbol  Number of Variants
# 0                                                   -                9802
# 1                                          A-GAMMA3'E                   2
# 2   A-GAMMA3'E;BGLT3;HBE1;HBG1;HBG2;HS-E1;LOC10609...                   1
# 3                                                A1BG                 172
# 4                                            A1BG-AS1                   8
# 5                                                A1CF                 140
# 6                             A1CF;ASAH2B;PRKG1;SGMS1                   2
# 7                                                 A2M                 466
# 8                                             A2M-AS1                   2
# 9          A2M;A2ML1;KLRG1;M6PR;MFAP5;PHC1;PZP;RIMKLB                   1
# 10                          A2M;A2ML1;KLRG1;M6PR;PHC1                   1
# 11                                          A2M;KLRG1                   2
# 12                            A2M;KLRG1;M6PR;PHC1;PZP                   1
# 13                                              A2ML1                3992
# 14                                            A3GALT2                  16
# 15                                             A4GALT                 282
# 16                                     A4GALT;ARFGAP3                   3
# 17  A4GALT;ATP5MGL;CYB5R3;NFAM1;POLDIP3;RRP7A;SERH...                   1
# 18                                              A4GNT                 118
# 19                                         A4GNT;DBR1                   1

# %%
import os
os.getcwd()
path = "/Users/adesinamary/Documents/GitHub/kondrashov/"
#os.mkdir('path')
os.listdir(path)
# Out:
# ['variable_sites_old.tsv',
#  'variable_sites.tsv',
#  'find_CPDs_Mary.ipynb',
#  'Clinvar_variants_written_from_database.txt',
#  'clinvar',
#  'clean_up_Mary.ipynb',
#  'kondrashov.py',
#  '.DS_Store',
#  'orthologs_xml_updated.ipynb',
#  'invalidated_CPDs_match_JUL31.tsv',
#  'protein_Sequence_length.txt',
#  'gene_transcript_changes.tsv',
#  'gencode.v50.metadata.HGNC.xlsx',
#  'Translation.xlsx',
#  'invalidated_CPDs.tsv',
#  'Variable_sites_match_29JUL.tsv',
#  'Clinvar_variants_written_from_database.xlsx',
#  'fasta',
#  'pathogenic',
#  'README.md',
#  'orthologs_Rodentia.ipynb',
#  'aln_match',
#  'Validate_CPDs_Mary.ipynb',
#  '.gitignore',
#  'fasta_match_Copy',
#  'fasta_match',
#  'find_closest.ipynb',
#  'Variable_sites_match_30JUL.tsv',
#  '.github',
#  'find_CPDs_Match.ipynb',
#  'orthologs.ipynb',
#  'orthologs_xml.ipynb',
#  '.ipynb_checkpoints',
#  'find_CPDs.ipynb',
#  '.git',
#  'orthologs_Mary_Primates.ipynb',
#  'find_closest_Mary.ipynb',
#  'clean_up.ipynb',
#  'aln_match - Copy',
#  'align.ipynb',
#  'pathogen_Mary.ipynb',
#  'orthologs_new.ipynb',
#  'pathogen.ipynb',
#  'aln']

# %%
run kondrashov

# %%
lociii
# Out:
# ['ABCA12',
#  'ABCD1',
#  'ACAD9',
#  'ACADM',
#  'ACADVL',
#  'ACAT1',
#  'ADA',
#  'AGL',
#  'AGXT',
#  'AHI1',
#  'AIRE',
#  'ALMS1',
#  'ALOX12B',
#  'ALPL',
#  'ANK1',
#  'ANO5',
#  'APC',
#  'AR',
#  'ARSA',
#  'ARSB',
#  'ASL',
#  'ASPA',
#  'ASPM',
#  'ATM',
#  'ATP7B',
#  'BBS2',
#  'BCKDHA',
#  'BEST1',
#  'BLM',
#  'BRIP1',
#  'BTD',
#  'BTK',
#  'CASR',
#  'CBS',
#  'CC2D2A',
#  'CDH23',
#  'CEP290',
#  'CERKL',
#  'CFTR',
#  'CHD7',
#  'CHEK2',
#  'CLN3',
#  'CNGB3',
#  'CPS1',
#  'CRB1',
#  'CTNS',
#  'CYBB',
#  'CYP11B1',
#  'CYP17A1',
#  'CYP27A1',
#  'DCLRE1C',
#  'DICER1',
#  'DUOX2',
#  'EHMT1',
#  'ELP1',
#  'ERCC6',
#  'EVC',
#  'EVC2',
#  'EXT1',
#  'EXT2',
#  'EYS',
#  'F7',
#  'F8',
#  'F9',
#  'FANCA',
#  'FANCI',
#  'FBN2',
#  'FKRP',
#  'FLCN',
#  'FRAS1',
#  'G6PD',
#  'GAA',
#  'GALC',
#  'GALNS',
#  'GALT',
#  'GBA1',
#  'GBE1',
#  'GCDH',
#  'GJB1',
#  'GLB1',
#  'GNE',
#  'GNPTAB',
#  'HBB',
#  'HEXA',
#  'HEXB',
#  'HGD',
#  'HGSNAT',
#  'HMBS',
#  'HPRT1',
#  'HPS3',
#  'IL2RG',
#  'ITGA2B',
#  'IVD',
#  'KCNH2',
#  'KCNQ1',
#  'KRIT1',
#  'L1CAM',
#  'LDLR',
#  'LIPA',
#  'LOXHD1',
#  'LPL',
#  'LRPPRC',
#  'LYST',
#  'MAN2B1',
#  'MCCC1',
#  'MCCC2',
#  'MED13L',
#  'MFN2',
#  'MKS1',
#  'MMUT',
#  'MPZ',
#  'MSH2',
#  'MTHFR',
#  'MUTYH',
#  'MYH7',
#  'NAGLU',
#  'NF1',
#  'NF2',
#  'NIPBL',
#  'NPC1',
#  'NSD1',
#  'OCA2',
#  'OPA1',
#  'PAH',
#  'PALB2',
#  'PAX3',
#  'PAX6',
#  'PCDH15',
#  'PCNT',
#  'PKHD1',
#  'PMM2',
#  'POMGNT1',
#  'PRPF31',
#  'PYGM',
#  'RAD50',
#  'RARS2',
#  'RECQL4',
#  'RHO',
#  'RP1',
#  'RPGRIP1L',
#  'SACS',
#  'SATB2',
#  'SCN4A',
#  'SERPING1',
#  'SGSH',
#  'SI',
#  'SLC12A6',
#  'SLC25A13',
#  'SLC26A4',
#  'SMPD1',
#  'SPAST',
#  'SPG11',
#  'SYNE1',
#  'TCIRG1',
#  'TMC1',
#  'TMEM67',
#  'TP53',
#  'TPP1',
#  'TSC1',
#  'TTR',
#  'TYR',
#  'UNC13D',
#  'USH1C',
#  'USH2A',
#  'VHL',
#  'VPS13A',
#  'VPS13B',
#  'VWF',
#  'WFS1',
#  'WRN',
#  'WT1',
#  'XPC',
#  'ZEB2',
#  'ZFYVE26']

# %%
variant_counts['GeneSymbol']
variant_counts
Clin1
#loci
# Out:
#                               Type  \
# 0                            Indel
# 1                            Indel
# 2                         Deletion
# 3                         Deletion
# 4        single nucleotide variant
# ...                            ...
# 8990430                   Deletion
# 8990431                   Deletion
# 8990432                   Deletion
# 8990433                   Deletion
# 8990434                   Deletion
#
#                                                       Name GeneSymbol  \
# 0        NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...      AP5Z1
# 1        NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...      AP5Z1
# 2           NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)      AP5Z1
# 3           NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)      AP5Z1
# 4             NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)     ZNF592
# ...                                                    ...        ...
# 8990430          NM_004621.6(TRPC6):c.1359del (p.Leu454fs)      TRPC6
# 8990431          NM_004621.6(TRPC6):c.2379del (p.Gly794fs)      TRPC6
# 8990432          NM_004621.6(TRPC6):c.2379del (p.Gly794fs)      TRPC6
# 8990433          NM_004621.6(TRPC6):c.1841del (p.Leu614fs)      TRPC6
# 8990434          NM_004621.6(TRPC6):c.1841del (p.Leu614fs)      TRPC6
#
#                  ClinicalSignificance Assembly
# 0        Pathogenic/Likely pathogenic   GRCh37
# 1        Pathogenic/Likely pathogenic   GRCh38
# 2                          Pathogenic   GRCh37
# 3                          Pathogenic   GRCh38
# 4              Uncertain significance   GRCh37
# ...                               ...      ...
# 8990430             Likely pathogenic   GRCh38
# 8990431             Likely pathogenic   GRCh37
# 8990432             Likely pathogenic   GRCh38
# 8990433             Likely pathogenic   GRCh37
# 8990434             Likely pathogenic   GRCh38
#
# [8990435 rows x 5 columns]

# %%
print(variant_counts[variant_counts["GeneSymbol"] == "BRCA1"])
# Out:
#      GeneSymbol  Number of Variants
# 4558      BRCA1               31226

# %%
import os
os.chdir('/Users/adesinamary/Documents/Variant_summary_genes/')

# %% [markdown]
# ## STEP 2
# ### For each gene filter variants with above 99 variants. Save output to .csv file

# %%
xx = ['ABCD1',
'ALPL',
'AR',
'BTK',
'CASR',
'CFTR',
'CYBB',
'F7',
'F8',
'F9',
'G6PD',
'GJB1',
'HBB',
'HPRT1',
'IL2RG',
'KCNH2',
'L1CAM',
'MPZ',
'MYH7',
'PMM2',
'RHO',
'TP53',
'TTR']

# %%
terms = ["Pathogenic", "Likely pathogenic", "Pathogenic/Likely pathogenic", "Pathogenic, low penetrance", "Likely pathogenic, low penetrance"]

for gene in sorted(lociii):
    variants = Clin1[
        (Clin1["GeneSymbol"] == gene) &
        (Clin1["ClinicalSignificance"].isin(terms)) &
        (Clin1["Type"] == "single nucleotide variant") &
        (Clin1["Assembly"] == "GRCh38")
    ]
    if len(variants) > 49:
        #variants.to_csv(f"/Users/adesinamary/Documents/GitHub/kondrashov/pathogenic_lociii/{gene}.csv", sep="\t", index=False)
        print(gene, len(variants), "variants exists")
            # to print the gene names in a list format for further analysis (lociii)
        # print(f"'{gene}',")
    else:
        ignore = True

    

    #print(variant_counts[variant_counts["GeneSymbol"] == gene])
# Out:
# ABCD1 327 variants exists
# ALPL 404 variants exists
# AR 269 variants exists
# BTK 244 variants exists
# CASR 206 variants exists
# CFTR 773 variants exists
# CYBB 141 variants exists
# F7 80 variants exists
# F8 512 variants exists
# F9 274 variants exists
# G6PD 207 variants exists
# GJB1 201 variants exists
# HBB 183 variants exists
# HPRT1 71 variants exists
# IL2RG 113 variants exists
# KCNH2 320 variants exists
# L1CAM 146 variants exists
# MPZ 143 variants exists
# MYH7 406 variants exists
# PMM2 174 variants exists
# RHO 173 variants exists
# TP53 414 variants exists
# TTR 130 variants exists
